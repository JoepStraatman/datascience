# %% [markdown]
# #  Assignment 5: Reproducability
#
# ## Notebook made by
#
# |** Name** | **Student id** | **email**|
# |:- |:-|:-|
# |. | | |
# |  | |. |
#
# ### Pledge (taken from [Coursera's Honor Code](https://www.coursera.org/about/terms/honorcode) )
#
#
#
# Put here a selfie with your photo where you hold a signed paper with the following text: (if this is team work, put two selfies here). The link must be to some place on the web, not to a local file.
#
# > My answers to homework, quizzes and exams will be my own work (except for assignments that explicitly permit collaboration).
#
# >I will not make solutions to homework, quizzes or exams available to anyone else. This includes both solutions written by me, as well as any official solutions provided by the course staff.
#
# >I will not engage in any other activities that will dishonestly improve my results or dishonestly improve/hurt the results of others.
#
# <img src='link to your selfie'/>
#
# ### Note
# * **Assignments without the selfies or completely filled in information will not be graded and receive 0 points.**

# %% [markdown]
#   We bekijken   het artikel <http://language.media.mit.edu/paper> en zien in hoeverre we uit de ruwe data dezelfde gegevens kunnen halen als de auteurs van het artikel. Eerst maken  we de netwerkdata gebaseerd op boekvertalingen.
#
# Daarna  gaan we de netwerkdata gebaseerd op de wikipedia data maken. De ruwe wikipedia "tsv" (voor tab separated) lijkt wel een spreadsheet, maar is in een onhandig formaat omdat de regels geen vast aantal kolommen hebben. We zullen dat eerst handmatig moeten oplossen.

# %%
# %matplotlib inline
import pandas as pd
import re
from lxml import etree 
from bz2file import BZ2File
import codecs
import nltk
from collections import defaultdict
from  itertools import combinations  # ideal for creating all possible pairs that one can make out of a set
from __future__ import division
from math import sqrt 
import itertools

# %% [markdown]
# # Deel boekvertalingen
#
# # 1
#
# Read the spreadsheet on `http://language.media.mit.edu/data/public/unesco_langlang_20120722_iso639-3.txt` directly in in pandas in a dataframe called `raw`, and show the first 5 lines of the dataframe `raw`.
#
# * this must be done in 2 lines

# %% [markdown]
# # 2
# We zijn natuurlijk in de Nederlandse taal geinterreseerd. Die heeft code `nld`.
#
# 1. Hoeveel regels zijn er in `raw` met `nld` in de kolom `original_language`
# 2. En hoeveel in de kolom `target_language`
# 3. Naar welke taal zijn er de meeste vertalingen vanuit het Nederlands?  Geef een one liner die de top 5 laat zien. Je laat alleen de kolommen `['target_language','num_translations']` zien, en eventueel de index kolom.
# 4. Maak een plotje met op de x-as de namen van talen omgekeerd geordend op het aantal vertalingen, en op de y-as hoe veel vertalingen er vanuit het Nederlands naar die taal is. Zorg dat de y-as in een log schaal geplot wordt.
#     * Je krijgt een wiebelige bijna rechte dalende curve. De x-as  begint met `deu`.

# %% [markdown]
# # 3
#
# Bekijk eens de output van `spannend= raw.original_language.value_counts()`. Gebruik `?` om uit te vogelen wat `value_counts` eigenlijk doet.
#
# 1. Beschrijf, gebruikmakend van terminologie uit de theorie van sociale netwerken, wat `spannend` betekent.
# 2. Wat betekent `raw.target_language.value_counts()` dan?
# 3. Maak een pandas Series object genaamd `total_translations` (een Dataframe met maar 1 kolom) met de taalcode als index en met voor elke taal het totaal aantal vertalingen vanuit die taal als waarde. Sorteer weer omgekeerd. De top 5 ziet er dan als volgt uit:
# ```
# eng    1225237
# fra     216624
# deu     201718
# rus     101395
# ita      66453
# ```
#     1. Plot `total_translations` in loglog schaal.
#     2. Wat is de waarde in `total_translations` voor het Nederlands?

# %% [markdown]
# # 4
#
# 1. Geef de mediaan en het gemiddelde van het aantal vertalingen.
# 2. Hoeveel taal-paren hebben meer vertalingen dan de mediaan?

# %% [markdown]
# # Deel  Wikipedia
#
#
#
# 1. Maak   van de Wikipedia _raw_ dataset de netwerk  datasets die op <http://language.media.mit.edu/data> beschreven staan.
# 2. We bekijken in hoeverre onze resultaten afwijken van die in de geleverde bewerkte datasets.
# 3. We leggen eventuele verschillen uit.
#
# #### In Stapjes
#
# We doen de opdracht in een aantal stapjes.
#
# #### Let op, je notebook moet vanzelf draaien. Alle data moet opgehaald worden.

# %% [markdown]
# # Download
#
# 1. Download de ruwe dataset als zip file, ontzip hem en sla hem in de directory op waarin dit notebook ook staat.
#     * Dit mag je met de hand doen. De code **moet niet runbaar** in je notebook staan.
#     * Maar zorg dat de rest van de code er vanuit gaat dat `wikipedia_userlang_iso639-3.tsv` in dezelfde folder staat als dit notebook
# 2. Lees de 2 bewerkte datasets over Wikipedia _Wikipedia Stats by Language_ en _Edges_ direct in van de urls in  pandas Dataframes, die je respectivelijk `dataset_stats_wikipedia` en `wikipedia_edges` noemt.
#     1. Maak de Taal code de index in het eerste frame, en hou alleen de Kolommen `['Editors', 'Edits','Multilinguals','Edits by mulitlinguals']`
#     2. Sorteer het frame op de index
#     2. Verwijder de kolommen `SourceLanguageName	TargetLanguageName	SourcePopulation	TargetPopulations` uit het tweede frame
#     3. Sorteer het frame op `SourceLanguageName`
#     3. Laat steeds met `head()` zien dat het werkt.
#
# ### Je antwoord bestaat uit 2 cellen

# %%
# jouw code hier 
dataset_stats_wikipedia = pd.read_csv('http://language.media.mit.edu/data/public/dataset_stats_wikipedia.tsv',delimiter='\t',encoding='utf-8',index_col='Language')
dataset_stats_wikipedia = dataset_stats_wikipedia[['Editors', 'Edits','Multilinguals','Edits by mulitlinguals']]
dataset_stats_wikipedia.sort_index()
dataset_stats_wikipedia.head()
#dataset_stats_wikipedia.get_value("Italian",'Edits')
# Out:
#            Editors   Edits  Multilinguals  Edits by mulitlinguals
# Language
# Abkhazian       15    2807              7                    1494
# Afar             4      46              3                       9
# Afrikaans      511  103652            352                   95988
# Akan            31     327             24                     240
# Albanian      1996  196685           1083                  137800

# %%
# jouw code hier  (verwijderen van de kolommen)
wikipedia_edges = pd.read_csv('http://language.media.mit.edu/data/public/wikipedia_edges.tsv',delimiter='\t',encoding='latin-1')
wikipedia_edges = wikipedia_edges.drop(['SourceLanguageName', 'TargetLanguageName', 'SourcePopulation', 'TargetPopulations'], axis=1)
wikipedia_edges.head()
# Out:
#   SourceLanguageCode TargetLanguageCode  Coocurrences  PhiCorrelation  \
# 0                afr                eng           271        0.013648
# 1                afr                nld            78        0.015377
# 2                amh                eng            28        0.004344
# 3                ang                eng            51        0.006363
# 4                ara                deu           446        0.007497
#
#    Tstatistic
# 0   17.207148
# 1    3.332197
# 2    5.476711
# 3    8.021067
# 4    3.550224

# %%
# jouw code hier  (sorten op SourceLanguageName)
wikipedia_edges = pd.read_csv('http://language.media.mit.edu/data/public/wikipedia_edges.tsv',delimiter='\t',encoding='latin-1')
wikipedia_edges.sort_values(by=['SourceLanguageName'])
wikipedia_edges.head()
# Out:
#   SourceLanguageCode TargetLanguageCode          SourceLanguageName  \
# 0                afr                eng                   Afrikaans
# 1                afr                nld                   Afrikaans
# 2                amh                eng                     Amharic
# 3                ang                eng  Old English (ca. 450-1100)
# 4                ara                deu                      Arabic
#
#   TargetLanguageName  SourcePopulation  TargetPopulations  Coocurrences  \
# 0            English               776             273987           271
# 1              Dutch               776              26888            78
# 2            English                81             273987            28
# 3            English               135             273987            51
# 4             German              6361             103768           446
#
#    PhiCorrelation  Tstatistic
# 0        0.013648   17.207148
# 1        0.015377    3.332197
# 2        0.004344    5.476711
# 3        0.006363    8.021067
# 4        0.007497    3.550224

# %% [markdown]
# # Haal gegevens uit de ruwe data, deel 1
#
# * De file `'wikipedia_userlang_iso639-3.tsv'` lijkt een spreadsheet maar hij heeft niet op elke regel evenveel kolommen.
# * Processing met pandas is dus ook lastig.
# * Als alternatief gaan we file zelf regel voor regel  inlezen, en de gewenste gegevens opslaan.
# * Ons einddoel is om een dataframe te maken dat er precies zo uitziet als `dataset_stats_wikipedia`
# * We doen dat in 2 stappen:
#     1. We maken een aantal dicts aan met de gewenste gegevens
#     2. Van elke dict maken we een dataframe met `pd.DataFrame.from_dict`
#     3. Die plakken we allemaal aan elkaar met `join` (neem een inner join)
#     4. Noem het eindresultaat `stats`, sorteer het ook op de index en laat het begin zien met `head`.
#     5. Check natuurlijk zelf of je op de goede weg zit door je resultaat te vergelijken met `dataset_stats_wikipedia`
# * Hieronder staat wat code om je op weg te helpen
# * **Lees het artikel en de supplementary material goed om net als zij de ruwe data te filteren.**
#
#
# # Haal gegevens uit de ruwe data, deel 2
#
# * In dezelfde code waarin je de vorige vraag hebt gemaakt, maak je ook een dict `pairs` aan. Hier zijn de sleutels paren van taalcodes, **waarbij de eerste altijd alfabetisch eerder is dan de tweede**, en hun waarde het aantal cooccurences.
# * Maak van dit dict een Dataframe `edges`, waarbij `edges.columns=['SourceLanguageCode','TargetLanguageCode','Coocurrencesmy']`
# * Sorteer ook hier op `'SourceLanguageCode'`
# * **Lees het artikel en de supplementary material goed om net als zij de ruwe data te filteren.**

# %%
# Your code 
with open('../wikipedia_userlang_iso639-3.tsv', encoding='latin-1') as f:
    c=0
    editors=defaultdict(int)
    edits=defaultdict(int)
    multilingual=defaultdict(int)
    Edits_by_mulitlinguals=defaultdict(int)
    pairs= defaultdict(int)
    c=0
    for l in f:
        if c <1000:
            print (l)
        # your code
        c+=1
        #if c% 10**5==0:  # om te debuggen doe ik hier 10**2==0: break 
            #print (c)
        
len(pairs)
# Out:
# ! ! ! ! ! ! ! ! ! ! ! ! ! ! !	zho,7
#
# ! ! ! ! ! ! ! ! ! ! ! ! ! !	zho,8
#
# ! ! ! ! ! ! ! ! ! ! ! ! !	zho,30
#
# ! ! ! ! ! ! ! ! ! ! ! !	zho,7
#
# ! ! ! ! ! ! ! ! ! ! !	zho,5
#
# ! ! ! albertzuro	deu,1
#
# ! !!	eng,1
#
# ! ..dr.guevara.. !	ara,1	eng,1
#
# ! 0lm	deu,252
#
# ! 8 jojo 8 !	deu,2
#
# ! aaÄa !	tur,31
#
# ! ari-ari-ari !	jpn,7
#
# ! biswas amitava !	eng,11
#
# ! danskammelsrod !	spa,9
#
# ! eini	deu,2
#
# ! god	cos,1	chv,1	vie,1	deu,1	sqi,1	wln,1	arg,1	rus,15	lav,1
#
# ! jay !	eng,3
#
# ! kaiser	sqi,5
#
# ! lash.rubberea.com	arc,1
#
# ! rbrider !	ces,1
#
# ! shz	pol,1
#
# ! the black spot !	eng,4
#
# ! tre e mezzo !	ita,1
#
# !! 'virgo rick' !!	eng,1
#
# !! db	eng,6
#
# !!! professional analism account! attaaaaaaaack!!!!	eng,2
#
# !!!!! lesen !!!!!!	deu,5
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!ola sexy boyz	eng,1
#
# !!!!!!!!!!!!!!!!!!!cammellobello	ita,10
#
# !!!!!!!!!!!!!!!	deu,2
#
# !!!!!adeen!!!!!	fin,365
#
# !!!!akamcia	pol,111
#
# !!!!miske	fin,2
#
# !!!!wikipedia is girls aloud free web hosting!!!	eng,4
#
# !!!(myestery dungeon)!!!	eng,1
#
# !!!alert!!!	ces,13
#
# !!!desperados!!!	deu,5
#
# !!!dr.gaio!!!	ita,10
#
# !!!dsavd	jpn,2
#
# !!!esdv	jpn,1
#
# !!!kjxfvyp	jpn,3
#
# !!!lolersk8!!!	eng,7
#
# !!!niloivenutfotuo	eng,1
#
# !!!please block this account. thank you	eng,2
#
# !!!rompeolas112!!!	spa,1
#
# !!!ruddingstone!!!	eng,1
#
# !!!s-tep-ha-n.cas!!!	deu,3
#
# !!!scottishrabbit!!!	eng,3
#
# !!!sr!!!	eng,2
#
# !!!whus!!!	ita,60
#
# !!!	jpn,82
#
# !!!××××××!!!	heb,6
#
# !!..:)	eng,1
#
# !!2011worldprotest!extra account	eng,1
#
# !!2011worldprotests!!appletart!!	eng,2
#
# !!2011worldprotests!!	eng,49
#
# !!8uyvasdaw	eng,8
#
# !!@!!	eng,2
#
# !!aaapplesauce	eng,3
#
# !!aaardyvark!!	eng,1
#
# !!aabgh!!	eng,1
#
# !!archie!!	eng,89
#
# !!conway-band!!	eng,1
#
# !!cpluvsds!!	eng,3
#
# !!cyber pinasco!!	ita,1
#
# !!ee	jpn,1
#
# !!gnikmra	eng,10
#
# !!house down!!	eng,70
#
# !!isheetoneggs!!	eng,1
#
# !!linfon!!	eng,2
#
# !!lokastory	fra,9
#
# !!mese!!	fin,9
#
# !!onpu	jpn,11
#
# !!rozz!!	spa,1
#
# !!samba2006!!	eng,2
#
# !!sgott	eng,28
#
# !!suzzy!!	tur,602
#
# !!vennin!!	eng,4
#
# !!viewcountfun1	eng,145
#
# !!wawawiwa!!	eng,37
#
# !!weed!!	jpn,12
#
# !!wrewe	jpn,5
#
# !!yeahman!!	deu,6
#
# !!yoshiryu!!	jpn,1
#
# !!	jpn,3	eng,1448
#
# !!æ­»ã­	ara,3
#
# !&quot;0000000000o00a	eng,1
#
# !&quot;mr.brightsides&quot;!	spa,1
#
# !&quot;Â£$%^&amp;*() +	eng,1
#
# !&quot;Â£$	eng,8
#
# !&quot;Â·$%&amp;	spa,2
#
# !)ark machine	eng,1
#
# !*!jodie-2007!*!	eng,5
#
# !*peter*!	eng,3
#
# !-!--:annekelol:--!-!	nld,1
#
# !-!z3ta!-!	spa,11
#
# !---slappdash---!	eng,128
#
# !--mk--!	fra,8
#
# !-artmaster	rus,2	ukr,216
#
# !-boingbag-!	eng,3
#
# !-raven thuqqin*	eng,1
#
# !-tiinkerbell-!	eng,2
#
# !.!.1	heb,14
#
# !.random.cutie.!	eng,1
#
# !1029qpwoalskzmxn	eng,3
#
# !157	jpn,6
#
# !1bhansen	eng,15
#
# !1qqaazz	eng,6
#
# !24a!	rus,4
#
# !51hans	deu,98
#
# !89 whipwap	eng,4
#
# !:.stann.:!	fra,3
#
# !? $prain me!	eng,6
#
# !?!	eng,3
#
# !?	fra,2	eng,2
#
# !@	pol,2
#
# !abacus	ita,6
#
# !achtung!	hbs,42
#
# !adrianzen25	spa,7
#
# !adrien!mg	fra,1
#
# !ai caramba!	spa,3
#
# !aikki!	fin,1
#
# !alfredo	fra,7
#
# !am olivier	fra,2
#
# !amor a la humanidad	spa,1
#
# !amthebest	tur,1
#
# !arrizog	eng,23
#
# !asdf7890	eng,1
#
# !astatine210isalo$er	eng,4
#
# !astep	ita,18
#
# !aunbos	eng,7
#
# !a	tha,4
#
# !babininja	eng,4
#
# !bamitsolly!	eng,5
#
# !barmaid	fra,13
#
# !bfvinfo	deu,15
#
# !biathlon!	nor,2
#
# !blardi	eng,5
#
# !bob+2!07	eng,7
#
# !bunk3r	eng,2
#
# !bur3au+	eng,2
#
# !c to the m!	eng,9
#
# !computeralert!	eng,151
#
# !coniiithawz	spa,1
#
# !con	eng,1
#
# !cow	eng,3
#
# !culturauniversalâ¢	spa,12
#
# !darkfire!6'28'14	eng,364
#
# !dem	fra,2
#
# !disney!	fin,1
#
# !do'worix	rus,7
#
# !dontdeserveyou	eng,1
#
# !dragon	eng,28
#
# !e!p!i!c!0!	eng,1
#
# !echo'schild!	eng,3
#
# !ed is cool!	eng,2
#
# !eddo0!	spa,8
#
# !edgaros1997!	rus,1
#
# !eebdfg	jpn,7
#
# !encyclopedialulzdramatica!	eng,2
#
# !eriikiita!	spa,1
#
# !exp	ita,22
#
# !e	pol,1	eng,2
#
# !fedk	por,6	eng,1
#
# !feel!the!lewls!	eng,2
#
# !flame! br	rus,5
#
# !frankee!	deu,3
#
# !frbzh	fra,5
#
# !gangsta g home dogg	eng,12
#
# !general4death!	deu,8
#
# !gnikmra	eng,4
#
# !go ben	eng,1
#
# !gravitation!	eng,1
#
# !g	spa,1
#
# !happy!days!	ita,1
#
# !hazel!	eng,10
#
# !hoax	fin,7
#
# !i!i!pq!i!i! 1	eng,1
#
# !i!i	jpn,3
#
# !ilgotah	jpn,6
#
# !inoi!	rus,1
#
# !iorgi!	eng,4
#
# !jackholeexplosion!	eng,1
#
# !jacktherabbit22	eng,1
#
# !jalen!	eng,1
#
# !jamieimaj!	eng,26
#
# !jeroen!	nld,2
#
# !jetta!	deu,2
#
# !jim	eng,208
#
# !joÃ£o0o0h!	por,2
#
# !jrb	eng,9
#
# !jÃº mc!	por,3
#
# !k!r!u!x!	deu,80
#
# !kairnmg!	eng,4
#
# !keegan!12	eng,2
#
# !l c r!	ita,1
#
# !lee!	lav,11	eng,3
#
# !llu$ion^	por,12	eng,18
#
# !lucius!	deu,2
#
# !maiban	rus,2
#
# !manly!	tur,1
#
# !mark	eng,2
#
# !mcbloobyenstein!!	eng,19
#
# !melquiades	eng,168
#
# !millhouse!	deu,3
#
# !mjriley!	eng,2
#
# !mm0	rus,41
#
# !mm4nu3l	deu,1
#
# !mnc99	eng,71
#
# !monkey!	eng,5
#
# !musiclova!	eng,9
#
# !my password is vand!	jpn,8
#
# !n memoriam	fra,4
#
# !nata bee	rus,3
#
# !nathan!	eng,3
#
# !ndream	eng,8
#
# !nenette	eng,1
#
# !nok	eng,3
#
# !normsl1ku	fra,38
#
# !notrub!	eng,34
#
# !nuf si noitabrutsam	eng,2
#
# !nxau	fin,1
#
# !o!!ercost!	eng,1
#
# !o0op	spa,3
#
# !omg deedee!	eng,2
#
# !paradigm!	eng,256
#
# !paradoxical!	eng,1
#
# !penzÂ¡	ita,150
#
# !phil!	deu,1
#
# !php!	msa,74
#
# !powa	ita,10
#
# !profgiorgia	ita,2
#
# !pso	fra,87	eng,1
#
# !pxl!	fra,2
#
# !q2w3e4r5t	eng,1
#
# !qil.7vl	jpn,3
#
# !qwerty789	jpn,6
#
# !raw ta skrowelppa	eng,2
#
# !regara!	eng,1
#
# !remagoediv	eng,4
#
# !rfqgw	jpn,1
#
# !rick	deu,33
#
# !ronstone	eng,71
#
# !rÂ¡â¬	spa,187	ita,1
#
# !saturdaynightwrist	eng,8
#
# !saw	jpn,1
#
# !sayhello	hun,60
#
# !seakingdood	eng,7
#
# !seakinggirl	eng,2
#
# !seakingman	eng,18
#
# !seakingmoose	eng,1
#
# !seakingwoman	eng,1
#
# !sergejmaksimovfromlatvia	eng,5
#
# !sethgash!	eng,7
#
# !silent old	fra,8
#
# !silent	fra,10	ita,14	por,23932	deu,9	eng,85
#
# !sln-btsts!	tur,28
#
# !spencer!new	eng,5
#
# !spoodem	eng,9
#
# !spooky	eng,1
#
# !sqwf	jpn,1
#
# !staring upwards!	eng,3
#
# !stvan	eng,1
#
# !sugarcrush!	eng,1
#
# !switzerdutsch!	deu,1
#
# !take it-to the-chorus!	eng,1
#
# !tch!	rus,7
#
# !the!bear!max!	eng,7
#
# !toddly!	eng,1
#
# !unalation	eng,1
#
# !vandos!	eng,1
#
# !vezzo! ll10	ita,4	eng,6
#
# !vft!	eng,1
#
# !vft	eng,2
#
# !vsdv	jpn,2
#
# !wacfd	jpn,4
#
# !wake up aryans	fas,24	eng,1
#
# !waraz!	fin,8
#
# !whfbhg&amp;^gg	eng,3
#
# !ww	jpn,6
#
# !x!	ita,3
#
# !x0bile	eng,9
#
# !x=gianluca=x!	ita,1
#
# !xathopeg	eng,3
#
# !xlfkdk	fra,1
#
# !xo derek	eng,22
#
# !xo-bling	eng,1
#
# !xobile123	eng,3
#
# !xoshizzle	eng,25
#
# !xxnemethxx!	eng,5
#
# !xxxvortecxxx!	eng,1
#
# !yantit!	deu,15
#
# !yesmelissa!	eng,5
#
# !zero!	deu,5
#
# !zzie	eng,3
#
# !zzy	slk,3
#
# !	rus,1	slv,15	deu,7	heb,4	eng,97
#
# !ç³æ¶	zho,56
#
# !×× ×	heb,2
#
# !ã»ã³ã	jpn,8
#
# !×× ××	heb,2
#
# !ÐÐµÐ½Ð¸Ñ ÐÐµÐ¾Ð½Ð¾Ð²!	rus,1
#
# !ÐÑÐ¼Ð½Ð°Ñ!	rus,1
#
# !à¤¸à¤¦à¥à¤§à¤°à¥à¤®à¤ªà¥à¤£à¥à¤¡à¤°à¥à¤ à¤¸à¥à¤¤	jpn,3
#
# $ 175 dollar	deu,1
#
# $ drummer king $	spa,1
#
# $ joÃ£o $ rico $	por,7
#
# $ london apartments	eng,54
#
# $ lugh $	tur,1
#
# $ madhu music $	eng,1
#
# $!ara	eng,19
#
# $!lv3r	deu,5
#
# $!m9191	fra,16
#
# $$ turns arise $$1	eng,3
#
# $$$ doesnt matter 2n8	deu,1
#
# $$$ fierce d $$$	eng,6
#
# $$$ young moneyz $$$	eng,2
#
# $$$$knjbvbv	fra,2
#
# $$$- bce -$$$	deu,14
#
# $$$dorababa$$$	hun,1
#
# $$$gabigyuro$$$	hun,2
#
# $$$gabri3l$$$	eng,2
#
# $$$idoyidunno	eng,1
#
# $$$jx408	eng,2
#
# $$$m.f.p.i.m.p$$$	eng,2
#
# $$$makemore$$$	eng,32
#
# $$$marlon$$$30	fra,1	jpn,2	eng,60	ita,8	lat,6	spa,8
#
# $$$marlon$$$	spa,1
#
# $$$mav$$$	eng,3
#
# $$$pelicano$$$	por,1
#
# $$$ronit rollz$$$	eng,1
#
# $$$t-t-h$$$	eng,6
#
# $$$	pol,1	deu,117
#
# $$%gjfdkjn	eng,1
#
# $$'s and sense	eng,2
#
# $$dkamkikazi$$	eng,1
#
# $$dragonjump$$	eng,4
#
# $$drichinsnukka14$$	eng,7
#
# $$haley$$	deu,4
#
# $$joyserg$$	spa,1
#
# $$kandtlicous ma	eng,1
#
# $$pervoietasch$$	deu,33	eng,1
#
# $$ply1968rr	eng,1
#
# $$ya boi rickey$$	eng,2
#
# $$your-mother$$	deu,1
#
# $$yuka con huevo$$	eng,3
#
# $%^$lexitk$%^$	eng,1
#
# $%^^%^&amp;&amp;((&amp;*(&amp;&amp;()*^*^&amp;%^&amp;%%&amp;*%regara**&amp;*^&amp;^%&amp;%	eng,1
#
# $%	eng,1
#
# $-s!mo-$	ita,2
#
# $-vrt	eng,139
#
# $.:undiscoverdalliancemember:.$	eng,3
#
# $.a.m.u.e.l.$	deu,60
#
# $.t.u.m.	spa,1
#
# $0.01 gummybear	eng,1
#
# $01734071290912$	eng,57
#
# $0nata	fra,1
#
# $0ny	nor,3
#
# $0	jpn,2
#
# $10 madness	eng,1
#
# $1000000000ten0one1	eng,294
#
# $13dg3	eng,13
#
# $1kk	ces,1
#
# $1lence d00600d	deu,3	eng,12243
#
# $1lence d0600d	eng,15
#
# $1ng3rb0y93	ita,5	eng,3
#
# $200inaire	eng,89
#
# $250923854abc	zho,39
#
# $285,908.04!? ka-ching!	eng,3
#
# $293,021.57!! dayam(!), lookadit climb!	eng,11
#
# $295,040.16!? i cant believe it!!	eng,3
#
# $301,179.46!!! wowie! zowie! kapowie!!	eng,8
#
# $350	zho,5
#
# $3ph1r0+h	jpn,3
#
# $3th1998	eng,6
#
# $4projects	eng,1
#
# $4	swe,2
#
# $5 gas will urth kids!	eng,5
#
# $5 gas will urth people	eng,3
#
# $5 gas	eng,12
#
# $5forme	eng,10
#
# $5lylt	eng,1
#
# $6 milkshake	eng,2
#
# $6milliondollarman	eng,24
#
# $766,642.76..!..!...!...holy !!! caniusethisname,please?	eng,5
#
# $8.40&amp;me	eng,10
#
# $?	eng,10
#
# $@lv@t!0n	deu,4
#
# $@r@h	eng,8
#
# $aaab	deu,1
#
# $abita $harma	eng,1
#
# $acrament0	eng,1
#
# $agataha!kiewicz$	pol,1
#
# $ahin	deu,11
#
# $aiyapimp	eng,1
#
# $alinochka kvitkevich$	rus,1
#
# $alman ansari	eng,1
#
# $alomee	fra,3
#
# $alome	deu,7
#
# $alu	swe,63
#
# $am0var	ita,545	eng,1
#
# $amppu	fin,2
#
# $ampson	eng,1
#
# $am	deu,3
#
# $andaker	nor,7
#
# $andi hartke	eng,1
#
# $andnesboy	nor,2
#
# $andokan	deu,5
#
# $andollar	eng,3
#
# $antander	eng,903
#
# $ari$41	eng,14
#
# $arlund	eng,1
#
# $arou	fra,11
#
# $array	deu,9
#
# $atan$ellscheapcredit	eng,3
#
# $atan's$pawn	eng,91
#
# $atan	nor,2
#
# $aurabh	eng,1
#
# $avage bea$t	eng,1
#
# $ayce	fra,7
#
# $bling$bling$	eng,1
#
# $brollin	eng,8
#
# $c0rp1u$	rus,1
#
# $cammer	eng,143
#
# $carfac3	eng,2
#
# $carlos=y	spa,25	eng,4
#
# $cathk	zho,1
#
# $ceridian1	eng,8
#
# $ch3mbri	eng,1
#
# $cieno $itter	eng,5
#
# $cirisme	eng,9
#
# $cj	eng,7
#
# $corpion	nld,2
#
# $cottrocc$	eng,1
#
# $crooge	nor,2
#
# $cyberwiz$	eng,29
#
# $d buu$	eng,3
#
# $de la raza$	eng,2
#
# $deluxe247$	eng,1
#
# $dollarz$	eng,9
#
# $dzyville$	eng,1
#
# $eba5111998	pol,1
#
# $ebastian	deu,3
#
# $ecnfdibq	rus,4
#
# $einte	eng,1
#
# $elias	deu,3
#
# $eph1ro+h	jpn,1
#
# $epp	deu,2
#
# $ept7	eng,3
#
# $erg29	rus,15
#
# $ergey13	dan,2
#
# $ergio 0923	eng,5
#
# $ergiu$	spa,4
#
# $ergiu	ron,1
#
# $eriaÂ£$olider	fra,2
#
# $eti	eng,115
#
# $evki	deu,3
#
# $eyran	rus,1
#
# $g0ld l34d3r$	eng,6
#
# $gabriel%	spa,1
#
# $giuseppe$	ita,23
#
# $gp-$v-tnk	jpn,1
#
# $gtedrock	eng,2
#
# $h!7	eng,1
#
# $h!fty	eng,12
#
# $h!t $0n	eng,1
#
# $h0rty 1893	deu,1
#
# $h31d0n.101	eng,1
#
# $h3li	ces,3
#
# $ha8una	eng,4
#
# $haan	eng,4
#
# $had0w	deu,45
#
# $hadow grinch	eng,8
#
# $hadow-x	eng,12
#
# $hadow1723	eng,1
#
# $hady j	eng,5
#
# $hady suniga!	eng,1
#
# $hady$hystergeithner	eng,15
#
# $hakesbeer	rus,51
#
# $hanakaz	eng,1
#
# $hanazzy	eng,1
#
# $hanice-16	eng,11
#
# $hapka	eng,2
#
# $harath	kan,8
#
# $haronlind$ay	eng,2
#
# $hifty1981	eng,3
#
# $horrtie	eng,1
#
# $hrine	eng,17
#
# $huja ahmed	eng,1
#
# $h	deu,3
#
# $iam676	ceb,5
#
# $ickboy	spa,1
#
# $id	eng,120
#
# $ifan1912	eng,31
#
# $igmund	eng,1
#
# $ikh gangsta	eng,4
#
# $ikhgangsta11	eng,2
#
# $ilencer	eng,5
#
# $ilence	fin,1
#
# $ilversettoexplode	eng,4
#
# $imo 95	ita,9
#
# $imon	slv,3
#
# $imple design	eng,1
#
# $imple	eng,4
#
# $imÃ¸ÃÃ¸Ãti	ita,11
#
# $indbad	eng,11
#
# $ircacota	spa,2
#
# $izzler $ajal	eng,2
#
# $j$m	fra,1
#
# $jaison$	deu,5
#
# $jennnet$	eng,1
#
# $johne89	eng,5
#
# $johnny rocket$	eng,2
#
# $jonathannnnnnn	eng,1
#
# $k83rb01	eng,1
#
# $kelet0r	eng,2
#
# $kevanh	eng,3
#
# $klother$74	eng,2
#
# $kooter-p	eng,1
#
# $kraypa	eng,3
#
# $kreena patel	eng,1
#
# $kull	deu,3
#
# $larrymuel	eng,1
#
# $lash65	eng,3
#
# $lash	hun,1
#
# $laurent	fra,16
#
# $lave yourself	eng,1
#
# $laveryworldwideinc	eng,9
#
# $layer1982	eng,1
#
# $leazy411	eng,4
#
# $leazypeazy	eng,2
#
# $ledzik	pol,3
#
# $liam hawkins$	eng,1
#
# $lick9109	eng,7
#
# $lil-tony92$	eng,1
#
# $lin02	rus,4
#
# $lisa$	deu,1
#
# $liw	pol,1	deu,1
#
# $loatgerg!	eng,1
#
# $look$likeans	eng,5
#
# $ly the flasher	fra,4
#
# $lyngblade	eng,1
#
# $m1th rus	rus,17
#
# $m1th09	eng,1
#
# $magnetic$	rus,6
#
# $mallin$	deu,3
#
# $mathe94$	fra,2	eng,18	por,2	deu,522	ita,2	pol,2	spa,3	cat,1
#
# $mathurin$74	fra,1
#
# $miÅey-miÅey	hun,2
#
# $mokey	nld,6
#
# $mone$	eng,1
#
# $moneymaniac$	eng,1
#
# $mr richboy $	eng,3
#
# $n0w0n3	spa,17
#
# $nake420	eng,9
#
# $nake887	eng,5
#
# $nakezz	eng,3
#
# $negovik	rus,1
#
# $nevesso$	eng,16
#
# $nn00Å¦i-i	eng,4
#
# $nowman916	eng,1
#
# $nowtiger	eng,1
#
# $occer ball	eng,2
#
# $olanum	eng,113
#
# $olemnolive	eng,6
#
# $oli d---lj$	deu,2
#
# $olid $nake	pol,12
#
# $oliton	eng,1
#
# $on of thug$	ara,8
#
# $onata	por,2
#
# $onn&quot;	deu,1
#
# $onny	deu,41
#
# $orienome$	zho,11
#
# $orienomesh	zho,3
#
# $osher$123564	heb,2
#
# $otk2	fin,16
#
# $oul$old	eng,2
#
# $our diesel	eng,1
#
# $outhpole	eng,2
#
# $owa	pol,3
#
# $p0ng3b0b	eng,5
#
# $p1tf1r3	eng,7
#
# $paulocgil$	por,2
#
# $payn- kok$	rus,2
#
# $pd2000	deu,1
#
# $peak cinema	pol,7
#
# $pecialuser	deu,34
#
# $peedfreak	deu,7
#
# $pencer1126	eng,2
#
# $pider	eng,5
#
# $pike	deu,4
#
# $pongey	eng,2
#
# $pooky	pol,3	ita,1
#
# $pr1te	rus,223
#
# $pringeragh	eng,4
#
# $quarry11	eng,2
#
# $quirrel14	eng,1
#
# $r89uy	deu,4
#
# $rir@m	eng,2
#
# $sam$	spa,1
#
# $sesty	fra,7
#
# $slimswitch$	eng,1
#
# $sponge$	hun,1
#
# $svenny$	deu,1
#
# $t!13tt0	rus,30
#
# $tack $tackk$	eng,1
#
# $talker (ss)	rus,3
#
# $tarchman!	spa,2
#
# $tatic	rus,309	arg,1	eng,8
#
# $taypuffmarshmellowman	eng,1
#
# $teaua	eng,2
#
# $teelboy	eng,1
#
# $tefanie	eng,1
#
# $tepandrago$	ron,1
#
# $ter!:ng	eng,6
#
# $teven	nor,98	eng,15
#
# $teverin0	eng,1
#
# $teve	eng,12
#
# $thedollarsign$	eng,74
#
# $timyoandrew7mero	eng,2
#
# $tink0man	eng,40
#
# $tinu$	deu,31
#
# $toic	rus,684	ita,1	deu,1	eng,8
#
# $too$h	ita,696
#
# $traight-$hoota	spa,2	fra,1	ita,1	deu,4979	eng,68
#
# $traigt-$hoota	lat,2
#
# $tranger	eng,1
#
# $trassenjunge	eng,2
#
# $trategery	eng,2
#
# $trategy	eng,1
#
# $trife	eng,3
#
# $truppi	deu,1
#
# $tudent	eng,2
#
# $tupid !mage	eng,3
#
# $u$an	pol,2
#
# $ub-zero	tur,2
#
# $ubzero	deu,1
#
# $udhir	eng,7
#
# $ultan bl	eng,7
#
# $un$hine$	eng,2
#
# $unatko	rus,1
#
# $up3rg1rl	eng,9
#
# $upa dee	eng,1
#
# $upagurl	eng,2
#
# $uper $tar	eng,2
#
# $uper-7	rus,1	fra,1	por,1	deu,8	nld,2
#
# $uperb$ujay	eng,1
#
# $uperbadd420	eng,3
#
# $uperman 5	eng,10
#
# $uppe	deu,11
#
# $uricate	eng,14
#
# $vennik	dan,1
#
# $vva110vv	rus,1
#
# $weet t00th	eng,4
#
# $weetdude69	eng,9
#
# $wguser	eng,156
#
# $wish	eng,4
#
# $witche$	eng,1
#
# $xano$granat$	deu,1
#
# $yd!	eng,2420
#
# $ydney	fra,12
#
# $yenalb$	eng,7
#
# $yeti	eng,7
#
# $ykotic	eng,2
#
# $ylv1	fra,1
#
# $zoom24	eng,3
#
# $	eng,57	swe,4	deu,1	cat,3	epo,2	spa,2	rus,1310
#
# $Ã«fo!!	fra,13
#
# $Ã¸Ã¸Æ¶	fra,1
#
# $×©××¨$	heb,1
#
# $×××× ×× ××× ×××$	heb,3
#
# $×××× ××××$	heb,1
#
# $ãã«ã­ã$	jpn,3
#
# $××¨×× ×$	heb,2
#
# % 55 % tour % 55 % oo n	eng,2
#
# %%%%	kor,17
#
# %1lox47doa	eng,2
#
# %95	eng,1
#
# %=)	eng,7
#
# %bobbobert1	eng,1
#
# %man of%s	eng,6
#
# %pier%	ita,15677
#
# %pointeror	eng,1
#
# %xxtrackingcookiexx%	eng,1
#
# %	slv,23	afr,3	eng,2
#
# %ÙÙÙÙ Ø§ÙØ¹ÙØ²Ù%	ara,1
#
# &amp;%@$^!$	eng,1
#
# &amp;&amp;kiirstenxrawr	eng,2
#
# &amp;*iskeyed	eng,8
#
# &amp;1daniel	sqi,1
#
# &amp;2a	pol,4
#
# &amp;aqwÃ©zsx	fra,7
#
# &amp;canarie	jpn,3
#
# &amp;delta	eng,51
#
# &amp;e	deu,2
#
# &amp;fritze	deu,4
#
# &amp;ghà½à¸à¤µà¤¿ä¹¦ç¿ãå¤©***	heb,7
#
# &amp;hearts:madelynn&amp;hearts:	eng,1
#
# &amp;heartstigger&amp;hearts	eng,1
#
# &amp;micate&amp;	fra,24
#
# &amp;mnt&amp;	tur,1
#
# &amp;orz-lololol	eng,5
#
# &amp;rei	ron,3
#
# &amp;rinks	jpn,1
#
# &amp;rogyny	eng,1
#
# &amp;ry	pol,1
#
# &amp;shiy;	eng,2
#
# &amp;sigmaf;:-&amp;zeta;)&amp;xi;	fra,33
#
# &amp;thinsp	eng,4
#
# &amp;var	eng,1
#
# &amp;	spa,1	fra,1	deu,2
#
# &amp;Â£$%;?@!!!	eng,3
#
# &amp;Ã©&quot;'(-Ã¨ Ã§Ã )=poiuytreza	fra,1
#
# &amp;Ã©&quot;'(-Ã¨ Ã§Ã )=	fra,13
#
# &lt;dvanw&gt;	fra,6
#
# &quot; harcerz diablo&quot;	pol,1
#
# &quot; vonny zaenal dien &quot;	msa,3
#
# &quot;&quot;	eng,20
#
# &quot;(user)&quot; &quot;(user...)&quot; &quot;(username)&quot; &quot;(usernameblock)&quot;	eng,1
#
# &quot;192.53.102.105&quot;	deu,3
#
# &quot;54n77u!&quot;	fin,3
#
# &quot;7Ã¯&amp;Ã!-!Ã´Å«&quot;	fra,5
#
# &quot;aaabc&quot;	eng,3
#
# &quot;ace&quot;	slv,1
#
# &quot;alyosha&quot;	eng,587
#
# &quot;anyone&quot; can edit?...well, alright!!	eng,10
#
# &quot;ast6 &quot;the best	ara,3
#
# &quot;athletic&quot; yeller	eng,3
#
# &quot;ayÃ³oÅikan!&quot;	eng,1
#
# &quot;bigfd&quot;	eng,2
#
# &quot;billidols&quot;	eng,3
#
# &quot;black gecko&quot; venom	ita,1
#
# &quot;cardinalen&quot;	fra,1	est,1	eng,35	swe,134	deu,14	nor,2	ita,1	pol,3	nld,1	bul,1	spa,1	lat,1	rus,2	nds,1	fin,145	zho,1
#
# &quot;catherine oliphant&quot;	eng,1
#
# &quot;cethegus&quot;	deu,31
#
# &quot;country&quot; bushrod washington	eng,1629
#
# &quot;crazy hann&quot;	spa,4
#
# &quot;crime dog&quot; mcgriff	eng,1
#
# &quot;cyanide&quot; by metallica	eng,1
#
# &quot;d&quot; jv	eng,1
#
# &quot;d&quot;	eng,615
#
# &quot;da puzzy lovas&quot;	eng,1
#
# &quot;dance magic show1&quot;	eng,6
#
# &quot;der&quot;schuster	deu,2
#
# &quot;dkv&quot;ii	eng,2
#
# &quot;download from a parkbench&quot;	eng,7
#
# &quot;dr.&quot; kernwein	eng,13
#
# &quot;e&quot;lympia	eng,1
#
# &quot;e.t.&quot;	eng,1
#
# &quot;echo&quot; ngo	hye,2
#
# &quot;emily-xd&quot;	fin,9
#
# &quot;en vd&quot;	swe,3
#
# &quot;eric sean&quot; casucci	eng,1
#
# &quot;every planet has a north&quot;	eng,1
#
# &quot;excuse me, sir&quot;	eng,2
#
# &quot;fengselsfugl&quot;	nor,1
#
# &quot;fog46horn&quot;	eng,4
#
# &quot;four-eyes&quot; girl with ape	eng,1
#
# &quot;g&quot; millitare	eng,1
#
# &quot;glorius&quot; gloria	eng,4
#
# &quot;good&quot; editer	eng,2
#
# &quot;gothic jj&quot;	fra,10
#
# &quot;hank&quot; kissinger	eng,1
#
# &quot;hardcore&quot; myth mayhem	eng,2
#
# &quot;head&quot; of state	eng,1
#
# &quot;hoes hoes hoes&quot; said santa	eng,2
#
# &quot;honest&quot; kid	eng,5
#
# &quot;in avos' we trust&quot;	rus,3	eng,3
#
# &quot;indians&quot;	eng,3
#
# &quot;inkhaw&quot;	tha,44
#
# &quot;ipsa scientia potestas est&quot;	eng,1
#
# &quot;james&quot; 559	eng,1
#
# &quot;jamy&quot; jen &amp; amy	eng,15
#
# &quot;jans322	eng,22
#
# &quot;jerk, beefy!&quot;	eng,90
#
# &quot;jewmakin me crazy!&quot; cries snrub	eng,3
#
# &quot;john&quot; 7hjg8	eng,7
#
# &quot;k&quot; simir	deu,1
#
# &quot;kelliyne` .	eng,1
#
# &quot;klar&quot;-v	deu,1
#
# &quot;kleriker&quot;	deu,1
#
# &quot;knife&quot; sotelo	eng,4
#
# &quot;kp&quot;	eng,15
#
# &quot;krÃ¼ppel&quot;hh	deu,4
#
# &quot;lenrenberg&quot;	fin,21
#
# &quot;lil beastly tha godfather&quot;	eng,2
#
# &quot;luna&quot; 21	spa,4
#
# &quot;magic in the moonlight&quot;	eng,6
#
# &quot;maike&quot;	deu,2
#
# &quot;me2d&quot;fubu	msa,2
#
# &quot;moo&quot; he farted	eng,1
#
# &quot;moo&quot; he replied	eng,3
#
# &quot;moo&quot; he thought	eng,6
#
# &quot;moo&quot; he typed	eng,2
#
# &quot;my feelings don't matter*&quot;	eng,1
#
# &quot;mz&quot;	nor,2
#
# &quot;napulitano&quot; per forza	nap,15
#
# &quot;new user&quot;	eng,4
#
# &quot;nos dessins animÃ©s 70-80&quot;	fra,9
#
# &quot;not i,&quot; said i.	eng,4
#
# &quot;not&quot; janine	rus,2
#
# &quot;only those who have experienced it can understand it.&quot;	eng,1
#
# &quot;ordi31&quot;	fra,1
#
# &quot;pal&quot; bucker	eng,1
#
# &quot;pana-da beast&quot;	eng,5
#
# &quot;pforra&quot;	bar,1
#
# &quot;primitive revolutionaries of china	eng,71
#
# &quot;prof&quot; north	eng,2
#
# &quot;pu$h0&quot;	eng,1
#
# &quot;pyrtsix&quot;	fin,4
#
# &quot;queen b&quot;	eng,3
#
# &quot;quillspen&quot;	eng,1
#
# &quot;r dub 54&quot;	eng,6
#
# &quot;ramu&quot; ramakrishna reddy	eng,18
#
# &quot;right guard&quot; ian	eng,1
#
# &quot;rom ram&quot;	ara,2
#
# &quot;runter vom gas!&quot;	deu,6
#
# &quot;sagan&quot;-zane	eng,4
#
# &quot;shk,casi filosofo&quot;	spa,1
#
# &quot;slim&quot; jim swenson	eng,5
#
# &quot;sockpupper&quot;	eng,2
#
# &quot;song (reprise)&quot;	eng,6
#
# &quot;sonntag&quot;	dan,5
#
# &quot;stone cold&quot; steve austin	por,15
#
# &quot;super-serial&quot;student94	eng,1
#
# &quot;suspected&quot; sockpuppet of hamish ross	eng,2
#
# &quot;swine&quot;flu=stolenfarmland	eng,3
#
# &quot;tequilla&quot; &quot;trinity&quot;	msa,1
#
# &quot;terrible simplifiers&quot;	eng,3
#
# &quot;testaccount	zho,4
#
# &quot;the eagle&quot; dynamite	fra,66
#
# &quot;the enemy has opted 4 oblivion!&quot;	eng,3
#
# &quot;the game&quot;tripleh	rus,23
#
# &quot;the hurricane&quot; gustav	eng,3
#
# &quot;the insane&quot; mikeal ranes	eng,6
#
# &quot;the yellow dart&quot;	eng,2
#
# &quot;the&quot; dylan	eng,2
#
# &quot;the&quot; jim smith	eng,4
#
# &quot;the&quot; trev	eng,10
#
# &quot;the&quot;arvoma	swe,1
#
# &quot;they are the assassins&quot;	eng,1
#
# &quot;time, marches on!&quot;	eng,1
#
# &quot;tonton--------du------bled&quot;	eng,1
#
# &quot;tu eres el templo&quot;	spa,1
#
# &quot;tuna75&quot;	fin,5
#
# &quot;understanding managed futures&quot;	eng,2
#
# &quot;unforgetteble&quot;	eng,4
#
# &quot;untouched&quot; phil	eng,1
#
# &quot;v&quot; for vashon	eng,4
#
# &quot;v&quot;forvolatility	eng,3
#
# &quot;we fly no lie!&quot;	eng,1
#
# &quot;weird al&quot; yankovic	eng,9
#
# &quot;weird mario&quot; garfield	eng,2
#
# &quot;where is home?&quot; by paul lambis	eng,1
#
# &quot;wrong is right&quot; band	rus,8	ukr,2
#
# &quot;yes&quot;rhyme-dentity	jpn,15
#
# &quot;z&quot;lawliet	msa,1
#
# &quot;zsÃ¡mbÃ©ker&quot;	hun,1
#
# &quot;	zho,17	eng,27
#
# &quot;Ð«&quot; Ñ Ð½Ð¾Ð³Ð°Ð¼Ð¸ Ð¸ ÑÑÐºÐ°Ð¼Ð¸	rus,1
#
# &quot;ÐÐÐ Ð ÐÐ¢ÐÐÐÐ&quot;	ukr,1
#
# &quot;××¨×× ×©××× × ××¨×&quot;	heb,1
#
# &quot;Ø§ÙØ¨Ø±Ù Ø§ÙÙØ§Ø¯Ø¦&quot;	ara,2
#
# &quot;ÐÑÐ´Ð»ÑÐ½Ð½Ñ Ð²ÑÐºÑÐ²&quot;	ukr,38
#
# &quot;ÐÐºÐ°Ð´ÐµÐ¼Ð¸Ñ Ð»Ð¸ÑÐ½Ð¾ÑÑÐ¸&quot;	ukr,4
#
# ' knog knog! '	tha,2	eng,1
#
# ' lvf3	spa,2
#
# ' l	eng,1
#
# ' rtnjkk()	eng,8
#
# ' vick	ron,2
#
# '' soul explorer&quot;	eng,5
#
# '''grysyv'''	nor,1
#
# '''idonia'''	fra,1
#
# ''ak'' (the rapper)	eng,12
#
# ''christoper jones''	eng,8
#
# ''dbenbenn''	eng,2
#
# ''klever	deu,4
#
# ''latino heat'' eddie guerrero	eng,16
#
# ''rapunzel''	zho,5
#
# ''the one and only''	eng,1
#
# ''thewayiam''	spa,3
#
# ''ÐÐµÐ½Ð³ÑÑÑ''	ukr,56
#
# '); drop table en user	eng,14
#
# '57 zephyr	eng,1
#
# '58plymouth	eng,1
#
# '63 chesapeake	eng,19
#
# '65 pontiac	eng,3
#
# '67 shelby mustang	eng,1
#
# '70folkjamboree'sphoto	jpn,4
#
# '73 rally sport camaro	eng,5
#
# '74 jailbreak	eng,15
#
# '84 greywolf	eng,2
#
# '91 hermit	pol,17
#
# '95twincam	eng,11
#
# 'a kiskiralylÃ¡ny'	hun,8
#
# 'a'chzen	deu,4
#
# 'a;s	eng,4
#
# 'abd al qayyum	fra,37
#
# 'agger	sag,42
#
# 'akwprejv	eng,22
#
# 'alexarrrrrrndramarie	eng,4
#
# 'althoof knock out'	eng,5
#
# 'alucard!	fra,23
#
# 'angel'	eng,17
#
# 'aq-n-itn	spa,170
#
# 'arry boy	eng,881
#
# 'av some of that	eng,7
#
# 'ave ya got any chuddy?	eng,4
#
# 'bitter coffee	rus,4
#
# 'blaze'	eng,7
#
# 'cause it's no good	eng,13
#
# 'chaotic! lee	por,2
#
# 'chuzard	eng,1
#
# 'cien	fra,37	nld,1
#
# 'cyclopedian	eng,1
#
# 'cystis	eng,4
#
# 'dacie'	zho,1
#
# 'dejo olowu	eng,3
#
# 'doc' scurlock	eng,1
#
# 'ebed	eng,4
#
# 'ello!!wikiperson	eng,1
#
# 'ellobeast	eng,1
#
# 'es man	eng,3
#
# 'expert' tom	eng,1
#
# 'ey gringo!	eng,21
#
# 'facemacgregor	eng,3
#
# 'felipe uchiha'	spa,19
#
# 'ff'lo	eng,27
#
# 'fghgearlkghaueo	eng,2
#
# 'flow	eng,23
#
# 'fritz'	deu,82
#
# 'geen'	nld,1
#
# 'good will' religion	eng,1
#
# 'hanna brewski	fra,1
#
# 'horns06	eng,10
#
# 'ifest 2011 iitr'	eng,1
#
# 'ilmulhaq	eng,10
#
# 'inyan	fra,39332	deu,1	heb,33	eng,56
#
# 'irnehnal	eng,1
#
# 'ivan47'	rus,1
#
# 'ivan	eng,277
#
# 'iw 'ip ghomey	eng,10
#
# 'iysh	eng,4
#
# 'izz	eng,4
#
# 'javii olave	spa,1
#
# 'jedi	swe,3
#
# 'jn its hi 4	eng,6
#
# 'k4p1.	pol,1
#
# 'katcookie'	eng,9
#
# 'keith campbell the 2nd'	eng,1
#
# 'kfja;lv	eng,1
#
# 'kill-kount' ollie	eng,7
#
# 'king steez' one	eng,5
#
# 'kj;kd a;ladks;lf adsr	eng,2
#
# 'laa anii	spa,3
#
# 'lbetta	ita,1
#
# 'lexy	eng,3
#
# 'lil' em 9	eng,2
#
# 'lildrummerkid12	eng,1
#
# 'lola'	deu,4
#
# 'malikoena	eng,1
#
# 'matiilda	swe,4
#
# 'matt'hieu phar'matt'ien	fra,8
#
# 'maximee	nld,1
#
# 'merikan	eng,45
#
# 'meyers01	nld,6
#
# 'monica lopez c.	eng,1
#
# 'munch'	eng,2
#
# 'naathaalia	por,1
#
# 'nadda	eng,1
#
# 'ncilu	scn,7
#
# 'ndrangheta	eng,20
#
# 'neon'	pol,2
#
# 'netwanderer	eng,2
#
# 'niloticus	fin,54
#
# 'niquemusic	eng,2
#
# 'njnj;t bvz	rus,1
#
# 'o salentino	ita,7
#
# 'o'merdo	tur,2
#
# 'o'	eng,5
#
# 'o. la zagna	lat,3	ita,2	bul,11	eng,2
#
# 'ocoo	eng,4
#
# 'orghenya'ngan	eng,1
#
# 'orghenya'	eng,10
#
# 'orrible cabbage	eng,1
#
# 'ow do?	eng,12
#
# 'oy'dasiqjaj	eng,5
#
# 'paaki' krishnan parthasarathy	tam,2
#
# 'paclife	fra,2
#
# 'phoney' depp	eng,1
#
# 'q' vakalalabure	eng,1
#
# 'rchino	ita,1
#
# 'rogis95	rus,1
#
# 'rogis	rus,5
#
# 's jÃ¶rgl	deu,9
#
# 's-gravenhage	eng,31
#
# 'sed	eng,48
#
# 'shivam 'izaa' rockkstarr'	eng,2
#
# 'slinger	eng,1
#
# 'solvo animus'	eng,1
# 0

# %%
# %%time
from collections import defaultdict
items = []
# Your code 
with open('../wikipedia_userlang_iso639-3.tsv', encoding = 'latin-1') as f:
    c=0
    editors=defaultdict(int)
    edits=defaultdict(int)
    multilingual=defaultdict(int)
    Edits_by_mulitlinguals=defaultdict(int)
    pairs= defaultdict(int)
    source = {}
    target = {}
    c=0
    for l in f:
        # your code
        temp = [x.replace("\n", "") for x in l.split("\t")[1:]]
        if len(temp) < 6:
            temp2 = [(x.split(',')[0],int(x.split(',')[1])) for x in temp]
            temp2 = [x for x in temp2 if x[1] > 1]
            if temp2:
                items.append(temp2)
        c+=1
        pairstemp= []
    
        for langs in temp2:
            
            editors[langs[0]] += 1
            edits[langs[0]] += langs[1]
            if len(temp2) > 1:
                multilingual[langs[0]] += 1
                Edits_by_mulitlinguals[langs[0]] += langs[1]
                pairstemp.append(langs[0])
                    
        if pairstemp:
            testje = list(itertools.permutations(pairstemp, 2)) 
            #print (testje)
            
            for thing in testje:
#                 if len(testje) > 2:
#                     print (thing)
#                     print ('________________________')
                pairs[(thing[0],thing[1])] += 1
                source[(thing[0],thing[1])] = thing[0]
                target[(thing[0],thing[1])] = thing[1]
# Out:
# Wall time: 21.4 s

# %%
#items[185:200]

# %%
deditors = pd.DataFrame.from_dict(editors, orient='index')
dedits = pd.DataFrame.from_dict(edits, orient='index')
#dedits.sort_index()
dmultilingual = pd.DataFrame.from_dict(multilingual, orient='index')
deditmultilingual = pd.DataFrame.from_dict(Edits_by_mulitlinguals, orient='index')
#dfs = [deditors, dedits, dmultilingual, deditmultilingual]
stats = pd.concat([deditors, dedits, dmultilingual, deditmultilingual],axis=1)
stats = stats.sort_index()
stats.columns=['Editors', 'Edits','Multilinguals','Edits by mulitlinguals']

# %%
#Deel 1
# jouw code hier 
stats.head()
# Out:
#      Editors   Edits  Multilinguals  Edits by mulitlinguals
# aar        9      57              4                      11
# abk       30    2842              7                    1494
# afr      658  104301            362                   96275
# aka       42     355             25                     242
# amh      116    4748             48                    4070

# %%
dpairs = pd.DataFrame.from_dict(pairs,orient='index')
dsource = pd.DataFrame.from_dict(source,orient='index')
dtarget = pd.DataFrame.from_dict(target,orient='index')
edges = pd.concat([dsource, dtarget, dpairs], axis=1)
edges.columns=['SourceLanguageCode','TargetLanguageCode','Coocurrencesmy']
edges = edges.sort_values(by=['SourceLanguageCode', 'TargetLanguageCode'])

# %%
#Deel2
edges.index = range(len(edges))
# jouw code hier 
edges.head(5)
# Out:
#   SourceLanguageCode TargetLanguageCode  Coocurrencesmy
# 0                aar                eng               1
# 1                aar                ipk               1
# 2                aar                ita               2
# 3                aar                mon               1
# 4                aar                sco               1

# %% [markdown]
# # Vergelijk
#
# We gaan nu onze dataframes vergelijken met die we hebben opgehaald.
#
# We zijn natuurlijk erg benieuwd of er verschillen zijn, en vooral ook groot die dan zijn, als ze er zijn.
#
# 1. Join `dataset_stats_wikipedia` en `stats` in een nieuwe dataframe `samen`.
#     * laat met `samen.describe()` zien hoe groot of klein de verschillen zijn
# 2. Maak een functie `fout_percentage` waar je twee kolommen en een dataframe aan geeft en die _het verschil tussen die twee kolommen bepaalt, en omzet naar een "foutpercentage"_.
# 3. Bereken dat percentage voor de vier kolommen `['Editors', 'Edits','Multilinguals','Edits by mulitlinguals']` en print het netjes uit.
# 4. Leg in een paar zinnen uit waarom jouw maat voor "foutpercentage" echt ergens op slaat, en het een goede indicator geeft.
# 5. Doe tenslotte hetzelfde voor `edges`.
#     * Hier doe je natuurlijk een `merge`
#     * Bekijk hier eens het verschil tussen een outer en een inner join.
#     * Leg uit wat er hier aan de hand is.
#     * Kan je het verschil verklaren?

# %%
# vergelijk stats met dataset_stats_wikipedia

samen =

def fout_percentage(col1,col2,df):
     # jouw code hier 

 

for col in stats.columns:
    print ("%s\t%s\t%s" %(col, fout_percentage(col, col+'my', samen))
# Out:
#   File "<ipython-input-182-0f1be816fd36>", line 3
#     samen=
#           ^
# SyntaxError: invalid syntax

# %%
samen.describe()

# %%
# vergelijk edges met "inner join"

# %%
# vergelijk edges met "outer join"

edges2=pd.merge(edges,wikipedia_edges, how='outer', on=['SourceLanguageCode','TargetLanguageCode'])
print (fout_percentage('Coocurrencesmy','Coocurrences', edges2))
edges2.describe()

# %% [markdown]
# # Reflectie
# Je hebt getracht een deel van het artikel te reproduceren. Ook hebben we gedacht over het artikel en de mate van herhaalbaarheid van de vermelde gegevens.
#
# Geef nu in een half A4 je eigen mening. Behandel deze twee punten:
#
# 1. Wat was al goed gedaan?
# 2. Wat kon beter en hoe dan?
