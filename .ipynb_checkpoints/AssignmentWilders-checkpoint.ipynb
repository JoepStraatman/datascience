# %% [markdown]
# #  Assignment 6
#
# ## Notebook made by
#
# |** Name** | **Student id** | **email**|
# |: |:-|:-|
# |Hidde de Haan |11028564 |Hiddedehaan@hotmail.com |
# |Joep Straatman |11035307 |Straatmanjoep@gmail.com |
# |  | |. |
#
#
#
# ### Pledge (taken from [Coursera's Honor Code](https://www.coursera.org/about/terms/honorcode) )
#
#
#
# Put here a selfie with your photo where you hold a signed paper with the following text: (if this is team work, put two selfies here). The link must be to some place on the web, not to a local file.
#
# > My answers to homework, quizzes and exams will be my own work (except for assignments that explicitly permit collaboration).
#
# >I will not make solutions to homework, quizzes or exams available to anyone else. This includes both solutions written by me, as well as any official solutions provided by the course staff.
#
# >I will not engage in any other activities that will dishonestly improve my results or dishonestly improve/hurt the results of others.
#
# <img src='http://i.imgur.com/3GMiSMB.jpg'/>
#
# ### Note
# * **Assignments without the selfies or completely filled in information will not be graded and receive 0 points.**

# %% [markdown]
# # Uitkomst
#
# In deze opdracht maken we de data netjes klaar  voor dit plaatje (uit een artikel in Vrij Nederland):
#
# <img src='http://politicalmashup.nl/uploads/2016/04/VN-interrupties_V3.png'/>

# %% [markdown]
# # XML opdracht
#
# * We gaan bekijken hoe vaak Wilders onderbroken wordt in de Tweede Kamer en door wie.
# * Als input files hebben we de Handelingen van de Tweede Kamer in keurig XML formaat.
# * Je kunt die bekijken op [overheid.nl](https://zoek.officielebekendmakingen.nl/zoeken/resultaat?zkt=Uitgebreid&pst=ParlementaireDocumenten&vrt=opening&zkd=AlleenInDeTitel&dpr=AnderePeriode&spd=20140101&epd=20160930&kmr=TweedeKamerderStatenGeneraal&sdt=KenmerkendeDatum&par=Handeling&dst=Onopgemaakt%7cOpgemaakt%7cOpgemaakt+na+onopgemaakt&isp=true&pnr=1&rpp=10)
#
# * Jouw taak is code te schrijven die 2 dingen doet:
#
#
# ### Data voor de opdracht
#
# <http://maartenmarx.nl/teaching/DataScience/Data/WildersXMLassignment>
#
# ## Taak 1
# Maak uit de XML bestanden in `TK_Handelingen_2013-2016.zip`  een bestand `interrupties.csv` met de volgende soort data: de kolommen zijn
# `'date','termijn','spreker','rol','indegree','aantal_interrupts','interruptors','interruptie_volgorde','OnderwerpDebat','url'` en dit is een voorbeeld.
#
#
# ```
# 20122013-10-15,1,Recourt,De heer,3,8,Van Raak-Van Raak-Van Raak-Pechtold-Pechtold-Pechtold-Van Ojik-Van Ojik,Begroting Algemene Zaken en begroting van de Koning,https://zoek.officielebekendmakingen.nl/h-tk-20122013-10-15.html
# 20122013-10-15,1,Van der Burg,Mevrouw,2,6,Thieme-Thieme-Pechtold-Pechtold-Pechtold-Pechtold,Begroting Algemene Zaken en begroting van de Koning,https://zoek.officielebekendmakingen.nl/h-tk-20122013-10-15.html
# 20122013-10-15,1,Bosma,De heer,0,0,,Begroting Algemene Zaken en begroting van de Koning,https://zoek.officielebekendmakingen.nl/h-tk-20122013-10-15.html
# 20122013-10-15,1,Van Toorenburg,Mevrouw,2,5,Pechtold-Pechtold-Pechtold-Bosma-Bosma,Begroting Algemene Zaken en begroting van de Koning,https://zoek.officielebekendmakingen.nl/h-tk-20122013-10-15.html
# 20122013-10-15,1,Van Raak,De heer,2,6,Recourt-Van der Burg-Van der Burg-Van der Burg-Recourt-Recourt,Begroting Algemene Zaken en begroting van de Koning,https://zoek.officielebekendmakingen.nl/h-tk-20122013-10-15.html
# ```
# * `termijn` is een integer dat de keer in het debat aangeeft dat de spreker vanaf het spreekgestoelte de zaal toespreekt. In de Kamer spreekt men van "eerste termijn" en "tweede termijn".
# * `indegree` betekent hier het aantal mensen dat `spreker` onderbroken heeft. `aantal_interrupts` is het totaal aantal keer dat een spreker onderbroken is.
# * Let op, de `date` kolom bevat niet echt een datum, maar is gemaakt van de filenaam: het is dus de periode, gevolgd door de hoeveelste vergadering in die periode, gevolgd het hoeveelste debat in die vergadering.
# * Let op, de filenamen zijn net ietsje anders dan deze waardes. Op deze manier is een eenvoudige sort voldoende om ze netjes chronologisch te krijgen.
#
# #### Let op
# Je zal zelf moeten uitvogelen hoe interrupties en sprekers etc in de XML zijn gecodeerd. Doe dit door de PDFs en HTML te bekijken, en desnoods een video van een debat.
#
# ## Taak 2
#
# Maak uit `interrupties.csv` met Pandas een dataframe wat er net zo uitziet als `Interruptors_van_Wilders.csv `.
# Die staat ook op <https://docs.google.com/spreadsheets/d/1PCOMeKV4-Y6_hZnN0o7-HxmrwSVLcP-ZP9vQK0DFLP8/edit#gid=49831024>
#
#
# ## Taak 3
#
# * Plot het aantal interrupties van Wilders per debat samen met het gemiddeld aantal interrupties in dat debat.
#     * Zet de "datums" op de x-as, en gebruik alleen die debatten waarin Wilders ook echt gesproken heeft.
#
#
# <hr/>
#
# # Taak 4 is optioneel in 2018. Je kunt hem  doen voor je miniproject.
#
# ## Taak 4
# * Verzin zelf iets bijzonders/geks/leuks met deze data, leg uit wat het betekent,  en laat je resultaat grafisch zien.
# * Verbind je onderzoeksvraag met de literatuur.
# * Je **moet** iets met tekst gaan doen. Je kunt met mutual information gaan spelen, met pos tagging, met sentiment analyse, met weet ik veel.
#
# #### Hier ben je heel vrij.
#
# Je kunt van alles doen. Dingen gaan tellen, maar allicht ook iets met de gesproken woorden doen. Wat suggesties:
#
# * Zeggen mannen andere dingen dan vrouwen?
# * Debatteren vrouwen anders dan mannen?
# * Vind de "stopwoordjes" van elke politicus.
# * IR-achtig: maak een model van elke politicus op basis van de woorden die zij heeft gezegd, en
# kijk dan (bijvoorbeeld met cosine-similarity) wie er veel op elkaar lijken.
# * Maak een netwerk van politici en laat zien wie er belangrijk is.
# * Bepaal het sentiment van politici, debatten, onderwerpen, ....
#
#
#
# # Let op
#
# * Maak je code zo dat **Wilders** een variabele wordt die aan het begin wordt gezet.
# * In jouw code moet ik die variabele kunnen vervangen door **Pechtold** of **Samson** of wie dan ook, dezelfde analyses uit taken 2-4 kunnen doen.

# %% [markdown]
# ## Taak 1
# Maak uit de XML bestanden in TK_Handelingen_2013-2016.zip een bestand interrupties.csv met de volgende soort data: de kolommen zijn 'date','termijn','spreker','rol','indegree','aantal_interrupts','interruptors','interruptie_volgorde','OnderwerpDebat','url' en dit is een voorbeeld

# %% [markdown]
# # voorbeeld
#     date                 : 20122013-10-15
#     termijn              : 1
#     spreker              : Recourt
#     rol                  : De heer
#     indegree             : 3
#     aantal_interrupts    : 8
#     interruptors         : Van Raak-Van Raak-Van Raak-Pechtold-Pechtold-Pechtold-Van Ojik-Van Ojik
#     interruptie_volgorde :
#     OnderwerpDebat       : Begroting Algemene Zaken en begroting van de Koning
#     url                  : https://zoek.officielebekendmakingen.nl/h-tk-20122013-10-15.html

# %%
import os
from zipfile import ZipFile
import glob
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
filezip = '../TK_Handelingen_2013-2016.zip'
if not os.path.exists("../handelingen"):
    os.makedirs("../handelingen")
    
    thefile = ZipFile(filezip)
    thefile.extractall("../handelingen")
    thefile.close()
    
locatie = '../handelingen/Wilders2014/'

# %%
def Taak_1(maplocation, teller):#print (re.findall(r"(\\n){5,6}\d*\\n(.+?)\\n",text.get_text()))
    num = 0
    dedict = {}
    date = []
    despreker = ''
    deaantalinteruptors = []
    deinteruptors = []
    for file in glob.glob(os.path.join(maplocation, '*.xml')):
        if num in teller:
            interuptors = []
            fileindex = os.path.basename(file).replace('.xml', '')[5:]
            with open(file, encoding="utf8") as f:
                text = BeautifulSoup(f.read())
                onderwerp = text.findAll('item-titel')
                
                if onderwerp:
                    onderwerp = onderwerp[0].text
                else:
                    
                    onderwerp = text.findAll('vergadering-nummer')
                    onderwerp = onderwerp[0].text
                    
                spreker = text.find_all('spreekbeurt')
                if spreker:
                    if spreker[0]['nieuw'] == 'ja':
                        despreker = spreker[0].findAll('achternaam')[0].text
                        
                        for item in spreker[1:]:

                            interuptors.append(item.findAll('achternaam')[0].text)
                            
                    else:
                        despreker = 'Voorzitter'# tijdelijk, ff kijken of dit klopt
                        for item in spreker:
                        
                            interuptors.append(item.findAll('achternaam')[0].text)
                    
                    
            aantalinteruptors = len(interuptors)
            dedict[fileindex] = [onderwerp,despreker, aantalinteruptors, interuptors]
        num += 1
        
    return dedict
# %time dictje = Taak_1(locatie,set(range(100)))
# Out:
# c:\users\gebruiker\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\gebruiker\appdata\local\programs\python\python36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Wall time: 1.82 s

# %%
dictje
# Out:
# {'20122013-1-1': ['1e vergadering', '', 0, []],
#  '20122013-1-2': ['Mededelingen', 'Voorzitter', 1, ['voorzitter']],
#  '20122013-1-3': ['Begroting 2013',
#   'Voorzitter',
#   6,
#   ['voorzitter',
#    'De Jager',
#    'De Jager',
#    'voorzitter',
#    'De Jager',
#    'voorzitter']],
#  '20122013-1-4': ['Regeling van werkzaamheden',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-10-1': ['10e vergadering', 'Voorzitter', 0, []],
#  '20122013-10-10': ['Stemmingen Postwet',
#   'Voorzitter',
#   3,
#   ['voorzitter', 'voorzitter', 'voorzitter']],
#  '20122013-10-11': ['Stemmingen ontslagen sociale werkplaatsen',
#   'Voorzitter',
#   3,
#   ['voorzitter', 'voorzitter', 'voorzitter']],
#  '20122013-10-12': ['Stemmingen Beperkingengebied buitenlandse luchthaven',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-10-13': ['Stemmingen algemene financiële beschouwingen',
#   'Voorzitter',
#   11,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-10-14': ['Stemmingen Subsidiariteitstoets veiligheid motorvoertuigen',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-10-15': ['Begroting Algemene Zaken en begroting van de Koning',
#   'Recourt',
#   64,
#   ['Van Raak',
#    'Recourt',
#    'Van Raak',
#    'Recourt',
#    'Van Raak',
#    'Recourt',
#    'Pechtold',
#    'Recourt',
#    'Pechtold',
#    'Recourt',
#    'Pechtold',
#    'Recourt',
#    'voorzitter',
#    'Van Ojik',
#    'Recourt',
#    'Van Ojik',
#    'Recourt',
#    'Van der Burg',
#    'Thieme',
#    'Van der Burg',
#    'Thieme',
#    'Van der Burg',
#    'Pechtold',
#    'Van der Burg',
#    'Pechtold',
#    'Van der Burg',
#    'voorzitter',
#    'Pechtold',
#    'Van der Burg',
#    'Pechtold',
#    'Bosma',
#    'Van Toorenburg',
#    'Pechtold',
#    'Van Toorenburg',
#    'Pechtold',
#    'Van Toorenburg',
#    'Pechtold',
#    'Van Toorenburg',
#    'voorzitter',
#    'Bosma',
#    'Van Toorenburg',
#    'Bosma',
#    'Van Toorenburg',
#    'Van Raak',
#    'Recourt',
#    'Van Raak',
#    'Van der Burg',
#    'Van Raak',
#    'Van der Burg',
#    'Van Raak',
#    'Van der Burg',
#    'Van Raak',
#    'Recourt',
#    'Van Raak',
#    'Recourt',
#    'Van Raak',
#    'Pechtold',
#    'Van Ojik',
#    'Van der Staaij',
#    'Pechtold',
#    'Van der Staaij',
#    'Pechtold',
#    'Van der Staaij',
#    'Thieme']],
#  '20122013-10-16': ['Openbare lichamen Bonaire, Sint Eustatius en Saba',
#   'Voorzitter',
#   93,
#   ['voorzitter',
#    'Spies',
#    'voorzitter',
#    'Segers',
#    'voorzitter',
#    'Hachchi',
#    'voorzitter',
#    'Van Oosten',
#    'voorzitter',
#    'Fritsma',
#    'Heijnen',
#    'Van Toorenburg',
#    'Van Raak',
#    'Heijnen',
#    'Van Raak',
#    'Heijnen',
#    'Van Raak',
#    'Heijnen',
#    'Van Raak',
#    'voorzitter',
#    'Spies',
#    'voorzitter',
#    'Spies',
#    'Van Raak',
#    'Spies',
#    'Van Raak',
#    'Spies',
#    'Segers',
#    'Spies',
#    'Segers',
#    'Spies',
#    'Hachchi',
#    'Spies',
#    'Hachchi',
#    'Spies',
#    'Segers',
#    'Spies',
#    'Segers',
#    'Spies',
#    'Segers',
#    'Spies',
#    'Hachchi',
#    'Spies',
#    'Hachchi',
#    'Spies',
#    'voorzitter',
#    'Hachchi',
#    'Spies',
#    'Van Raak',
#    'Spies',
#    'Van Raak',
#    'Spies',
#    'voorzitter',
#    'Van Raak',
#    'Spies',
#    'Van Oosten',
#    'Spies',
#    'Van Oosten',
#    'Spies',
#    'Heijnen',
#    'Spies',
#    'Heijnen',
#    'Spies',
#    'Hachchi',
#    'Spies',
#    'Segers',
#    'Spies',
#    'Segers',
#    'Spies',
#    'Segers',
#    'Spies',
#    'voorzitter',
#    'Spies',
#    'voorzitter',
#    'Segers',
#    'Hachchi',
#    'Hachchi',
#    'Van Oosten',
#    'Hachchi',
#    'Van Oosten',
#    'voorzitter',
#    'Van Raak',
#    'voorzitter',
#    'Spies',
#    'Segers',
#    'Spies',
#    'voorzitter',
#    'Spies',
#    'Van Raak',
#    'Spies',
#    'Van Raak',
#    'Spies',
#    'voorzitter']],
#  '20122013-10-17': ['Ingekomen stukken', 'Voorzitter', 0, []],
#  '20122013-10-2': ['Vragenuur',
#   'Marcouch',
#   10,
#   ['Opstelten',
#    'Marcouch',
#    'Opstelten',
#    'Marcouch',
#    'Opstelten',
#    'voorzitter',
#    'Marcouch',
#    'Opstelten',
#    'Berndsen-Jansen',
#    'Opstelten']],
#  '20122013-10-3': ['Vragenuur',
#   'Bruins Slot',
#   19,
#   ['Schippers',
#    'Bruins Slot',
#    'Schippers',
#    'Bruins Slot',
#    'Schippers',
#    'Bouwmeester',
#    'Schippers',
#    'Straus',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Krol',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Klever',
#    'Schippers',
#    'Klever',
#    'voorzitter']],
#  '20122013-10-4': ['Vragenuur',
#   'Van Tongeren',
#   9,
#   ['Weekers',
#    'Van Tongeren',
#    'Weekers',
#    'Van Tongeren',
#    'Weekers',
#    'Neppérus',
#    'Weekers',
#    'Van Vliet',
#    'Weekers']],
#  '20122013-10-5': ['Vragenuur',
#   'Paulus Jansen',
#   10,
#   ['Spies',
#    'Paulus Jansen',
#    'Spies',
#    'Paulus Jansen',
#    'Spies',
#    'Monasch',
#    'Spies',
#    'Knops',
#    'Spies',
#    'voorzitter']],
#  '20122013-10-6': ['Vragenuur',
#   'Voordewind',
#   12,
#   ['voorzitter',
#    'Voordewind',
#    'voorzitter',
#    'Leers',
#    'Voordewind',
#    'Leers',
#    'Voordewind',
#    'Leers',
#    'De Wit',
#    'Leers',
#    'De Wit',
#    'voorzitter']],
#  '20122013-10-7': ['Mededelingen',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-10-8': ['Regeling van werkzaamheden',
#   'Voorzitter',
#   81,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'Agema',
#    'voorzitter',
#    'Venrooy',
#    'Leijten',
#    'Kuzu',
#    'voorzitter',
#    'Agema',
#    'voorzitter',
#    'Agema',
#    'voorzitter',
#    'voorzitter',
#    'Leijten',
#    'voorzitter',
#    'Agema',
#    'Venrooy',
#    'Bergkamp',
#    'Keijzer',
#    'Kuzu',
#    'voorzitter',
#    'Kuzu',
#    'Leijten',
#    'voorzitter',
#    'Leijten',
#    'voorzitter',
#    'voorzitter',
#    'Ouwehand',
#    'Schouw',
#    'Lodders',
#    'voorzitter',
#    'Geurts',
#    'voorzitter',
#    'Jacobi',
#    'Klaver',
#    'Van Gerven',
#    'voorzitter',
#    'De Graaf',
#    'voorzitter',
#    'Ouwehand',
#    'voorzitter',
#    'voorzitter',
#    'Van Raak',
#    'voorzitter',
#    'Van Raak',
#    'voorzitter',
#    'Van Raak',
#    'Fritsma',
#    'Van Dam',
#    'Van Raak',
#    'voorzitter',
#    'Van Raak',
#    'voorzitter',
#    'Van Raak',
#    'voorzitter',
#    'Van Dam',
#    'voorzitter',
#    'Van Raak',
#    'Van Toorenburg',
#    'voorzitter',
#    'Van Raak',
#    'voorzitter',
#    'voorzitter',
#    'Hachchi',
#    'voorzitter',
#    'Hachchi',
#    'Eijsink',
#    'voorzitter',
#    'Eijsink',
#    'Berckmoes-Duindam',
#    'Knops',
#    'voorzitter',
#    'De Roon',
#    'Segers',
#    'Jasper van Dijk',
#    'Van Tongeren',
#    'voorzitter',
#    'Hachchi',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-10-9': ['Stemmingen Wet schadeloosstelling',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-100-1': ['100e vergadering', 'Voorzitter', 0, []],
#  '20122013-100-10': ['Ingekomen stukken', 'Voorzitter', 0, []],
#  '20122013-100-2': ['Mededelingen', 'Voorzitter', 1, ['voorzitter']],
#  '20122013-100-3': ['Aanbevelingen Europese Commissie extra bezuinigingen',
#   'Voorzitter',
#   247,
#   ['voorzitter',
#    'Wilders',
#    'Roemer',
#    'Pechtold',
#    'Van Haersma Buma',
#    'voorzitter',
#    'Van Haersma Buma',
#    'Wilders',
#    'Van Haersma Buma',
#    'Wilders',
#    'Van Haersma Buma',
#    'Wilders',
#    'Van Haersma Buma',
#    'Thieme',
#    'Slob',
#    'Pechtold',
#    'Slob',
#    'Pechtold',
#    'Slob',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'voorzitter',
#    'Van Ojik',
#    'Samsom',
#    'Van Ojik',
#    'Samsom',
#    'Van Ojik',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Roemer',
#    'voorzitter',
#    'Roemer',
#    'Samsom',
#    'Slob',
#    'Samsom',
#    'Slob',
#    'Samsom',
#    'Slob',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'voorzitter',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van der Staaij',
#    'Samsom',
#    'Van der Staaij',
#    'Samsom',
#    'Van der Staaij',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'voorzitter',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'voorzitter',
#    'Van Ojik',
#    'Samsom',
#    'Van Ojik',
#    'Samsom',
#    'Van Ojik',
#    'Samsom',
#    'voorzitter',
#    'Samsom',
#    'Slob',
#    'Samsom',
#    'Slob',
#    'Samsom',
#    'voorzitter',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Roemer',
#    'Samsom',
#    'Roemer',
#    'voorzitter',
#    'Roemer',
#    'voorzitter',
#    'Samsom',
#    'Wilders',
#    'Samsom',
#    'Wilders',
#    'Samsom',
#    'Wilders',
#    'Samsom',
#    'Wilders',
#    'Samsom',
#    'voorzitter',
#    'Van Ojik',
#    'Van Ojik',
#    'Slob',
#    'Van Ojik',
#    'Slob',
#    'Van Ojik',
#    'Slob',
#    'Van Ojik',
#    'Roemer',
#    'Van Ojik',
#    'Van der Staaij',
#    'Zijlstra',
#    'Van Haersma Buma',
#    'voorzitter',
#    'Van Haersma Buma',
#    'Zijlstra',
#    'Van Haersma Buma',
#    'Zijlstra',
#    'Van Haersma Buma',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'voorzitter',
#    'Pechtold',
#    'voorzitter',
#    'Pechtold',
#    'Zijlstra',
#    'Van Ojik',
#    'Zijlstra',
#    'Van Ojik',
#    'Zijlstra',
#    'Van Ojik',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Roemer',
#    'voorzitter',
#    'Roemer',
#    'voorzitter',
#    'Roemer',
#    'Zijlstra',
#    'Van Haersma Buma',
#    'Zijlstra',
#    'Van Haersma Buma',
#    'Zijlstra',
#    'voorzitter',
#    'Wilders',
#    'Zijlstra',
#    'voorzitter',
#    'Pechtold',
#    'voorzitter',
#    'Pechtold',
#    'voorzitter',
#    'Wilders',
#    'voorzitter',
#    'Zijlstra',
#    'Slob',
#    'Zijlstra',
#    'Slob',
#    'Zijlstra',
#    'Slob',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'Van Ojik',
#    'Zijlstra',
#    'Van Ojik',
#    'Zijlstra',
#    'Van Ojik',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Pechtold',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Roemer',
#    'Van Haersma Buma',
#    'Zijlstra',
#    'Van Haersma Buma',
#    'Zijlstra',
#    'voorzitter',
#    'Krol',
#    'voorzitter']],
#  '20122013-100-4': ['Mededelingen', 'Voorzitter', 1, ['voorzitter']],
#  '20122013-100-5': ['Regeling van werkzaamheden',
#   'Voorzitter',
#   48,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Krol',
#    'Helder',
#    'Van Oosten',
#    'Omtzigt',
#    'Klaver',
#    'Ouwehand',
#    'Vermeij',
#    'Dik-Faber',
#    'Gesthuizen',
#    'voorzitter',
#    'Ouwehand',
#    'voorzitter',
#    'Van Tongeren',
#    'voorzitter',
#    'Van Veldhoven',
#    'Agema',
#    'Leegte',
#    'voorzitter',
#    'Leegte',
#    'voorzitter',
#    'Jan Vos',
#    'voorzitter',
#    'Jan Vos',
#    'voorzitter',
#    'Krol',
#    'Agnes Mulder',
#    'Dik-Faber',
#    'Ouwehand',
#    'voorzitter',
#    'Van Tongeren',
#    'voorzitter',
#    'Van Tongeren',
#    'voorzitter',
#    'Van Veldhoven',
#    'voorzitter',
#    'Van Toorenburg',
#    'voorzitter',
#    'Omtzigt',
#    'voorzitter',
#    'Omtzigt',
#    'voorzitter']],
#  '20122013-100-6': ['Aanbevelingen Europese Commissie bezuinigingen',
#   'Rutte',
#   174,
#   ['Roemer',
#    'Rutte',
#    'Pechtold',
#    'voorzitter',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Van der Staaij',
#    'Rutte',
#    'Van der Staaij',
#    'Rutte',
#    'Slob',
#    'Rutte',
#    'Slob',
#    'Rutte',
#    'Slob',
#    'Rutte',
#    'Van Ojik',
#    'Rutte',
#    'Van Ojik',
#    'Rutte',
#    'Van Ojik',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'voorzitter',
#    'Van Haersma Buma',
#    'Rutte',
#    'Krol',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Van Ojik',
#    'Rutte',
#    'Van Ojik',
#    'Rutte',
#    'Van Ojik',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'voorzitter',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'voorzitter',
#    'Wilders',
#    'Wilders',
#    'Wilders',
#    'Roemer',
#    'Pechtold',
#    'Pechtold',
#    'Van Haersma Buma',
#    'Slob',
#    'Van Haersma Buma',
#    'Slob',
#    'Van Haersma Buma',
#    'Krol',
#    'voorzitter',
#    'Thieme',
#    'Thieme',
#    'voorzitter',
#    'Slob',
#    'Pechtold',
#    'Slob',
#    'Pechtold',
#    'Slob',
#    'Pechtold',
#    'Slob',
#    'Van Ojik',
#    'Slob',
#    'voorzitter',
#    'Samsom',
#    'Pechtold',
#    'voorzitter',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Samsom',
#    'Pechtold',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Van Haersma Buma',
#    'Samsom',
#    'Thieme',
#    'Samsom',
#    'Thieme',
#    'Samsom',
#    'Thieme',
#    'Samsom',
#    'Van Ojik',
#    'Van der Staaij',
#    'Zijlstra',
#    'voorzitter',
#    'Pechtold',
#    'Zijlstra',
#    'Roemer',
#    'Zijlstra',
#    'Krol',
#    'voorzitter',
#    'Van Haersma Buma',
#    'voorzitter',
#    'Van Haersma Buma',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Thieme',
#    'Rutte',
#    'Thieme',
#    'Rutte',
#    'Thieme',
#    'Rutte',
#    'voorzitter',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'Roemer',
#    'Rutte',
#    'voorzitter',
#    'Asscher',
#    'Van Haersma Buma',
#    'Van Haersma Buma',
#    'Asscher',
#    'Zijlstra',
#    'Asscher',
#    'voorzitter']],
#  '20122013-100-7': ['Agenda Europese top',
#   'Voorzitter',
#   191,
#   ['voorzitter',
#    'Van Bommel',
#    'Klaver',
#    'Schouten',
#    'Verheijen',
#    'Klaver',
#    'Verheijen',
#    'Klaver',
#    'Verheijen',
#    'Pechtold',
#    'Verheijen',
#    'Pechtold',
#    'Verheijen',
#    'Pechtold',
#    'Verheijen',
#    'Van Haersma Buma',
#    'Verheijen',
#    'Van Haersma Buma',
#    'Verheijen',
#    'Klaver',
#    'Verheijen',
#    'Klaver',
#    'Verheijen',
#    'Madlener',
#    'Verheijen',
#    'Madlener',
#    'Verheijen',
#    'Schouten',
#    'Verheijen',
#    'Schouten',
#    'Verheijen',
#    'Madlener',
#    'Verheijen',
#    'Madlener',
#    'voorzitter',
#    'Pechtold',
#    'Verheijen',
#    'Pechtold',
#    'voorzitter',
#    'Pechtold',
#    'Verheijen',
#    'Pechtold',
#    'voorzitter',
#    'Pechtold',
#    'Bisschop',
#    'Pechtold',
#    'Bisschop',
#    'Pechtold',
#    'Bisschop',
#    'Madlener',
#    'Servaes',
#    'Madlener',
#    'Servaes',
#    'Madlener',
#    'Servaes',
#    'Madlener',
#    'Servaes',
#    'voorzitter',
#    'Servaes',
#    'voorzitter',
#    'Verheijen',
#    'Servaes',
#    'Verheijen',
#    'Servaes',
#    'Madlener',
#    'Servaes',
#    'Madlener',
#    'Servaes',
#    'voorzitter',
#    'Servaes',
#    'Van Haersma Buma',
#    'Verheijen',
#    'Van Haersma Buma',
#    'Verheijen',
#    'Van Haersma Buma',
#    'voorzitter',
#    'Rutte',
#    'Servaes',
#    'Rutte',
#    'Verheijen',
#    'Rutte',
#    'Van Bommel',
#    'Rutte',
#    'Van Bommel',
#    'Rutte',
#    'Madlener',
#    'Rutte',
#    'Madlener',
#    'Rutte',
#    'Servaes',
#    'Rutte',
#    'Servaes',
#    'Rutte',
#    'Madlener',
#    'Rutte',
#    'Madlener',
#    'Rutte',
#    'Van Haersma Buma',
#    'Madlener',
#    'Rutte',
#    'Madlener',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'voorzitter',
#    'Servaes',
#    'Rutte',
#    'Servaes',
#    'Rutte',
#    'Madlener',
#    'Rutte',
#    'Timmermans',
#    'Madlener',
#    'Timmermans',
#    'Madlener',
#    'Timmermans',
#    'Madlener',
#    'Timmermans',
#    'Madlener',
#    'voorzitter',
#    'Madlener',
#    'Timmermans',
#    'voorzitter',
#    'Madlener',
#    'Timmermans',
#    'Van Haersma Buma',
#    'Timmermans',
#    'Van Haersma Buma',
#    'Timmermans',
#    'Van Haersma Buma',
#    'Timmermans',
#    'Bisschop',
#    'Timmermans',
#    'Bisschop',
#    'Timmermans',
#    'voorzitter',
#    'Bisschop',
#    'Timmermans',
#    'voorzitter',
#    'Bisschop',
#    'Timmermans',
#    'voorzitter',
#    'Pechtold',
#    'Timmermans',
#    'Pechtold',
#    'Timmermans',
#    'Verheijen',
#    'Timmermans',
#    'Verheijen',
#    'Timmermans',
#    'voorzitter',
#    'Verheijen',
#    'voorzitter',
#    'Van Haersma Buma',
#    'voorzitter',
#    'Servaes',
#    'Timmermans',
#    'Servaes',
#    'Timmermans',
#    'Servaes',
#    'Timmermans',
#    'voorzitter',
#    'Van Bommel',
#    'Van Haersma Buma',
#    'Van Bommel',
#    'voorzitter',
#    'Segers',
#    'Verheijen',
#    'voorzitter',
#    'Bisschop',
#    'Madlener',
#    'Pechtold',
#    'Madlener',
#    'Madlener',
#    'voorzitter',
#    'Madlener',
#    'Madlener',
#    'Madlener',
#    'Servaes',
#    'Van Haersma Buma',
#    'Van Haersma Buma',
#    'Van Haersma Buma',
#    'Rutte',
#    'voorzitter',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'voorzitter']],
#  '20122013-100-8': ['Stemmingen moties Europese Top',
#   'Voorzitter',
#   10,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-100-9': ['Sluiting', 'Voorzitter', 0, []],
#  '20122013-101-1': ['101e vergadering', 'Voorzitter', 0, []],
#  '20122013-101-10': ['Verzoekschriften', 'Voorzitter', 0, []],
#  '20122013-101-11': ['Initiatiefvoorstel Huis voor klokkenluiders',
#   'Voorzitter',
#   27,
#   ['voorzitter',
#    'Ulenbelt',
#    'Litjens',
#    'Ulenbelt',
#    'Litjens',
#    'Ulenbelt',
#    'Van Toorenburg',
#    'Ulenbelt',
#    'Van Toorenburg',
#    'Ulenbelt',
#    'Van Toorenburg',
#    'Bisschop',
#    'Thieme',
#    'Bisschop',
#    'Thieme',
#    'Bisschop',
#    'Thieme',
#    'Bisschop',
#    'voorzitter',
#    'Bisschop',
#    'Berndsen-Jansen',
#    'Thieme',
#    'Bosma',
#    'Litjens',
#    'voorzitter',
#    'Tanamal',
#    'voorzitter']],
#  '20122013-101-12': ['Schulden- en armoedebeleid',
#   'Karabulut',
#   73,
#   ['Voortman',
#    'Voortman',
#    'Voortman',
#    'Schouten',
#    'Van Weyenberg',
#    'Schouten',
#    'Van Weyenberg',
#    'Schouten',
#    'voorzitter',
#    'Van Weyenberg',
#    'Kuzu',
#    'Karabulut',
#    'Kuzu',
#    'Karabulut',
#    'Kuzu',
#    'Potters',
#    'Kuzu',
#    'Voortman',
#    'Kuzu',
#    'Voortman',
#    'Kuzu',
#    'voorzitter',
#    'Van Weyenberg',
#    'Kuzu',
#    'Van Weyenberg',
#    'Kuzu',
#    'voorzitter',
#    'Klijnsma',
#    'Karabulut',
#    'Klijnsma',
#    'voorzitter',
#    'Karabulut',
#    'Klijnsma',
#    'voorzitter',
#    'Van Weyenberg',
#    'Klijnsma',
#    'Karabulut',
#    'Klijnsma',
#    'Karabulut',
#    'Klijnsma',
#    'Karabulut',
#    'Klijnsma',
#    'Karabulut',
#    'Klijnsma',
#    'Karabulut',
#    'Klijnsma',
#    'voorzitter',
#    'Karabulut',
#    'Klijnsma',
#    'voorzitter',
#    'Voortman',
#    'Klijnsma',
#    'Voortman',
#    'Klijnsma',
#    'voorzitter',
#    'Voortman',
#    'voorzitter',
#    'voorzitter',
#    'Karabulut',
#    'voorzitter',
#    'Klijnsma',
#    'Voortman',
#    'Klijnsma',
#    'voorzitter',
#    'Voortman',
#    'Klijnsma',
#    'voorzitter',
#    'Teeven',
#    'Kuzu',
#    'Teeven',
#    'Kuzu',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-101-13': ['Vreemdelingen- en asielbeleid',
#   'Voordewind',
#   43,
#   ['Voordewind',
#    'Fritsma',
#    'Gesthuizen',
#    'Gesthuizen',
#    'Gesthuizen',
#    'Voortman',
#    'Voortman',
#    'Van Hijum',
#    'Van Hijum',
#    'Van Hijum',
#    'Azmani',
#    'Van Hijum',
#    'Schouw',
#    'Schouw',
#    'Teeven',
#    'Fritsma',
#    'Teeven',
#    'Fritsma',
#    'Teeven',
#    'Fritsma',
#    'Teeven',
#    'Fritsma',
#    'Teeven',
#    'Voortman',
#    'Teeven',
#    'Voortman',
#    'Teeven',
#    'Voortman',
#    'Teeven',
#    'Van Hijum',
#    'Teeven',
#    'Van Hijum',
#    'voorzitter',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'voorzitter']],
#  '20122013-101-14': ['Nieuwe Masterplan DJI 2013-2018',
#   'Voorzitter',
#   325,
#   ['voorzitter',
#    'Kooiman',
#    'voorzitter',
#    'Helder',
#    'Van der Steur',
#    'Van Tongeren',
#    'Van der Steur',
#    'Van Tongeren',
#    'Van der Steur',
#    'Schouw',
#    'Van der Steur',
#    'Schouw',
#    'Van der Steur',
#    'voorzitter',
#    'Van der Steur',
#    'Helder',
#    'Van der Steur',
#    'Helder',
#    'Van der Steur',
#    'voorzitter',
#    'Helder',
#    'Van der Steur',
#    'Van Toorenburg',
#    'Van der Steur',
#    'Van Toorenburg',
#    'Van der Steur',
#    'Van Toorenburg',
#    'Van der Steur',
#    'Segers',
#    'Van der Steur',
#    'Segers',
#    'Van der Steur',
#    'Segers',
#    'Van der Steur',
#    'voorzitter',
#    'Van der Steur',
#    'voorzitter',
#    'Van der Steur',
#    'Kooiman',
#    'Van der Steur',
#    'Kooiman',
#    'Van der Steur',
#    'Kooiman',
#    'Van der Steur',
#    'voorzitter',
#    'Van der Steur',
#    'voorzitter',
#    'Van Toorenburg',
#    'Van der Steur',
#    'Van Toorenburg',
#    'Van der Steur',
#    'Van Toorenburg',
#    'Van der Steur',
#    'voorzitter',
#    'Van Tongeren',
#    'Van der Steur',
#    'voorzitter',
#    'Van der Steur',
#    'Van Tongeren',
#    'voorzitter',
#    'Van Tongeren',
#    'voorzitter',
#    'Van der Steur',
#    'voorzitter',
#    'Van Tongeren',
#    'Van der Steur',
#    'Schouw',
#    'voorzitter',
#    'Schouw',
#    'voorzitter',
#    'Schouw',
#    'Van Tongeren',
#    'Van der Staaij',
#    'Van Toorenburg',
#    'Klein',
#    'Segers',
#    'Marcouch',
#    'Kooiman',
#    'Marcouch',
#    'Kooiman',
#    'Marcouch',
#    'Kooiman',
#    'Marcouch',
#    'voorzitter',
#    'Marcouch',
#    'voorzitter',
#    'Marcouch',
#    'Segers',
#    'Marcouch',
#    'Segers',
#    'Marcouch',
#    'Segers',
#    'Marcouch',
#    'Segers',
#    'Marcouch',
#    'Schouw',
#    'Marcouch',
#    'voorzitter',
#    'Marcouch',
#    'voorzitter',
#    'Marcouch',
#    'Schouw',
#    'Marcouch',
#    'voorzitter',
#    'Schouw',
#    'Marcouch',
#    'Helder',
#    'Marcouch',
#    'Helder',
#    'Marcouch',
#    'Helder',
#    'Marcouch',
#    'voorzitter',
#    'Teeven',
#    'Schouw',
#    'voorzitter',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Van Tongeren',
#    'Teeven',
#    'Van Tongeren',
#    'Teeven',
#    'Van Tongeren',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Van Toorenburg',
#    'Teeven',
#    'Van Toorenburg',
#    'Teeven',
#    'Van Toorenburg',
#    'Teeven',
#    'Marcouch',
#    'Teeven',
#    'Helder',
#    'Teeven',
#    'Helder',
#    'Teeven',
#    'Helder',
#    'Teeven',
#    'Helder',
#    'voorzitter',
#    'Teeven',
#    'Van der Staaij',
#    'Teeven',
#    'Van Toorenburg',
#    'Teeven',
#    'Van Toorenburg',
#    'Teeven',
#    'voorzitter',
#    'Teeven',
#    'voorzitter',
#    'Kooiman',
#    'voorzitter',
#    'Kooiman',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'voorzitter',
#    'Van Toorenburg',
#    'voorzitter',
#    'Van Toorenburg',
#    'voorzitter',
#    'Van Toorenburg',
#    'voorzitter',
#    'Van Toorenburg',
#    'voorzitter',
#    'Schouw',
#    'voorzitter',
#    'Schouw',
#    'voorzitter',
#    'Schouw',
#    'voorzitter',
#    'Van Toorenburg',
#    'Teeven',
#    'Van Toorenburg',
#    'Teeven',
#    'Van Tongeren',
#    'Teeven',
#    'Van Tongeren',
#    'Teeven',
#    'Van Tongeren',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'voorzitter',
#    'Teeven',
#    'Helder',
#    'Teeven',
#    'Helder',
#    'Teeven',
#    'Van der Steur',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'Marcouch',
#    'Teeven',
#    'Van der Steur',
#    'Teeven',
#    'Van der Steur',
#    'Teeven',
#    'Van der Steur',
#    'Van Toorenburg',
#    'Teeven',
#    'Van Toorenburg',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Kooiman',
#    'Segers',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'voorzitter',
#    'Kooiman',
#    'Kooiman',
#    'voorzitter',
#    'Kooiman',
#    'Helder',
#    'Helder',
#    'voorzitter',
#    'Van der Steur',
#    'Kooiman',
#    'Van der Steur',
#    'Kooiman',
#    'Van der Steur',
#    'Schouw',
#    'Schouw',
#    'voorzitter',
#    'Van Tongeren',
#    'Van Tongeren',
#    'voorzitter',
#    'Van Toorenburg',
#    'Van Toorenburg',
#    'Van Toorenburg',
#    'Van Toorenburg',
#    'voorzitter',
#    'Van der Steur',
#    'Van Toorenburg',
#    'Klein',
#    'Segers',
#    'Marcouch',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Schouw',
#    'Teeven',
#    'voorzitter',
#    'Schouw',
#    'Teeven',
#    'voorzitter',
#    'Schouw',
#    'Teeven',
#    'Van Tongeren',
#    'voorzitter',
#    'Teeven',
#    'voorzitter',
#    'Teeven',
#    'voorzitter',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'Kooiman',
#    'Teeven',
#    'voorzitter',
#    'Van Toorenburg',
#    'Teeven',
#    'voorzitter',
#    'Van Toorenburg',
#    'voorzitter',
#    'Teeven',
#    'voorzitter',
#    'Teeven',
#    'Van Toorenburg',
#    'Teeven',
#    'Marcouch',
#    'voorzitter',
#    'Segers',
#    'Teeven',
#    'Segers',
#    'Teeven',
#    'Segers',
#    'voorzitter',
#    'Helder',
#    'Teeven',
#    'Helder',
#    'voorzitter',
#    'Teeven',
#    'voorzitter']],
#  '20122013-101-15': ['Sluiting', 'Voorzitter', 0, []],
#  '20122013-101-16': ['Ingekomen stukken', 'Voorzitter', 0, []],
#  '20122013-101-2': ['Mededelingen', 'Voorzitter', 1, ['voorzitter']],
#  '20122013-101-3': ['Regeling van werkzaamheden',
#   'Voorzitter',
#   21,
#   ['voorzitter',
#    'Vermeij',
#    'voorzitter',
#    'Vermeij',
#    'voorzitter',
#    'voorzitter',
#    'Dijkgraaf',
#    'Tony van Dijck',
#    'voorzitter',
#    'Tony van Dijck',
#    'voorzitter',
#    'Van Weyenberg',
#    'voorzitter',
#    'Ulenbelt',
#    'voorzitter',
#    'Van Hijum',
#    'voorzitter',
#    'Krol',
#    'voorzitter',
#    'Vermeij',
#    'voorzitter']],
#  '20122013-101-4': ['Rapport tijdelijke commissie Huizenprijzen',
#   'Voorzitter',
#   128,
#   ['voorzitter',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Dijkgraaf',
#    'Verhoeven',
#    'Dijkgraaf',
#    'Verhoeven',
#    'Van Klaveren',
#    'Verhoeven',
#    'Van Klaveren',
#    'Verhoeven',
#    'voorzitter',
#    'Verhoeven',
#    'Dijkgraaf',
#    'Verhoeven',
#    'Dijkgraaf',
#    'Verhoeven',
#    'Van Klaveren',
#    'Verhoeven',
#    'Van Klaveren',
#    'Verhoeven',
#    'Van Klaveren',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Visser',
#    'Verhoeven',
#    'voorzitter',
#    'Visser',
#    'Verhoeven',
#    'Visser',
#    'voorzitter',
#    'Verhoeven',
#    'Visser',
#    'Verhoeven',
#    'Visser',
#    'Verhoeven',
#    'voorzitter',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Koolmees',
#    'voorzitter',
#    'Verhoeven',
#    'Koolmees',
#    'Verhoeven',
#    'Monasch',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'voorzitter',
#    'Verhoeven',
#    'voorzitter',
#    'Dijkgraaf',
#    'Verhoeven',
#    'Dijkgraaf',
#    'Verhoeven',
#    'Visser',
#    'Verhoeven',
#    'Visser',
#    'Verhoeven',
#    'Visser',
#    'Verhoeven',
#    'Visser',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'voorzitter',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'Paulus Jansen',
#    'Verhoeven',
#    'voorzitter',
#    'Verhoeven',
#    'voorzitter',
#    'Verhoeven',
#    'voorzitter',
#    'Visser',
#    'Verhoeven',
#    'Visser',
#    'Verhoeven',
#    'Monasch',
#    'voorzitter',
#    'Monasch',
#    'Verhoeven',
#    'Monasch',
#    'Verhoeven',
#    'voorzitter',
#    'Monasch',
#    'Paulus Jansen',
#    'voorzitter',
#    'Fritsma',
#    'Koolmees',
#    'Monasch',
#    'Koolmees',
#    'Monasch',
#    'Koolmees',
#    'Monasch',
#    'Koolmees',
#    'Monasch',
#    'Koolmees',
#    'voorzitter',
#    'Koolmees',
#    'Visser',
#    'Visser',
#    'voorzitter',
#    'voorzitter',
#    'Verhoeven',
#    'voorzitter']],
#  '20122013-101-5': ['Mededelingen',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-101-6': ['Regeling van werkzaamheden',
#   'Voorzitter',
#   19,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'Agema',
#    'voorzitter',
#    'Krol',
#    'voorzitter',
#    'Leijten',
#    'Voortman',
#    'Bergkamp',
#    'voorzitter',
#    "Van 't Wout",
#    'voorzitter',
#    'Otwin van Dijk',
#    'Dik-Faber',
#    'Keijzer',
#    'voorzitter',
#    'Agema',
#    'voorzitter']],
#  '20122013-101-7': ['Stemmingen Verlaging maximumopbouw- en premiepercentages pensioen',
#   'Voorzitter',
#   6,
#   ['voorzitter',
#    'Van Weyenberg',
#    'Klein',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-101-8': ['Stemmingen Pensioenaanvullingsregelingen',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-101-9': ['Hamerstukken', 'Voorzitter', 0, []],
#  '20122013-102-1': ['102e vergadering', 'Voorzitter', 0, []],
#  '20122013-102-10': ['Stemmingen Raming Tweede Kamer',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-102-11': ['Stemming aangehouden motie Grote Merenregio',
#   'Voorzitter',
#   4,
#   ['voorzitter', 'voorzitter', 'Agnes Mulder', 'voorzitter']],
#  '20122013-102-12': ['Stemming motie Emancipatiebeleid',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-102-13': ['Stemming motie Luchtvaart',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-102-14': ['Stemmingen moties Windenergie op land',
#   'Voorzitter',
#   11,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-102-15': ['Stemmingen moties Gezondheidsaspecten leefomgeving',
#   'Voorzitter',
#   8,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-102-16': ['Stemmingen moties Leefomgeving',
#   'Voorzitter',
#   11,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-102-17': ['Stemmingen moties Mogelijke sluiting havo-vwo-afdelingen onderbouw van vmbo-scholen',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-102-18': ['Stemmingen moties Wijziging Mediawet 2008 stelsel publieke omroep',
#   'Voorzitter',
#   13,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'Klaver',
#    'voorzitter']],
#  '20122013-102-19': ['Stemmingen Wijziging Mediawet 2008 stelsel publieke omroep',
#   'Voorzitter',
#   11,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-102-2': ['Vragenuur: Vragen Leijten',
#   'Voorzitter',
#   13,
#   ['voorzitter',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'voorzitter',
#    'Wolbert',
#    'Schippers',
#    'voorzitter']],
#  '20122013-102-20': ['Stemmingen moties aanbevelingen Europese commissie bezuinigingen',
#   'Voorzitter',
#   8,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-102-21': ['Stemming motie rapport Parlementair onderzoek "Huizenprijzen"',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-102-22': ['Stemmingen moties Armoede- en schuldenbeleid',
#   'Voorzitter',
#   4,
#   ['voorzitter', 'voorzitter', 'voorzitter', 'voorzitter']],
#  '20122013-102-23': ['Stemmingen moties Vreemdelingen- en asielbeleid',
#   'Voorzitter',
#   13,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-102-24': ['Stemmingen moties nieuwe masterplan DJI',
#   'Voorzitter',
#   18,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-102-25': ['Stemmingen Brief EU teeltmateriaal',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-102-26': ['Stemmingen Brief EU markttoegang voor havendiensten',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-102-27': ['Stemmingen Brief EU netwerk- en informatiebeveiliging in de Unie',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-102-28': ['Stemmingen Brief Presidium tijdelijke commissie Fyra',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-102-29': ['Stemming aangehouden motie JBZ-Raad van 6 en 7 juni',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-102-3': ['Vragenuur: Vragen De Rouwe',
#   'De Rouwe',
#   14,
#   ['Mansveld',
#    'De Rouwe',
#    'voorzitter',
#    'De Rouwe',
#    'Mansveld',
#    'Van Veldhoven',
#    'Mansveld',
#    'Van Tongeren',
#    'Mansveld',
#    'voorzitter',
#    'Mansveld',
#    'Dik-Faber',
#    'Mansveld',
#    'voorzitter']],
#  '20122013-102-30': ['Stemmingen moties Jaarverslag ministerie van Veiligheid en Justitie 2012',
#   'Voorzitter',
#   3,
#   ['voorzitter', 'voorzitter', 'voorzitter']],
#  '20122013-102-31': ['Stemmingen moties Jaarverslag ministerie van Economische Zaken 2012',
#   'Voorzitter',
#   4,
#   ['voorzitter', 'voorzitter', 'voorzitter', 'voorzitter']],
#  '20122013-102-32': ['Stemming motie Beleidsnota "Wat de wereld verdient: een nieuwe agenda voor hulp, handel en investeringen"',
#   'Voorzitter',
#   1,
#   ['voorzitter']],
#  '20122013-102-33': ['Verslag Europese top',
#   'Voorzitter',
#   91,
#   ['voorzitter',
#    'Van Bommel',
#    'Pechtold',
#    'Verheijen',
#    'Tony van Dijck',
#    'Verheijen',
#    'Tony van Dijck',
#    'Verheijen',
#    'voorzitter',
#    'Verheijen',
#    'voorzitter',
#    'Madlener',
#    'Tony van Dijck',
#    'Servaes',
#    'Tony van Dijck',
#    'Servaes',
#    'Tony van Dijck',
#    'Servaes',
#    'Madlener',
#    'Servaes',
#    'Madlener',
#    'Servaes',
#    'Van Haersma Buma',
#    'Servaes',
#    'Van Haersma Buma',
#    'Servaes',
#    'Van Haersma Buma',
#    'voorzitter',
#    'Servaes',
#    'voorzitter',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'voorzitter',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'voorzitter',
#    'Van Haersma Buma',
#    'Rutte',
#    'Tony van Dijck',
#    'Rutte',
#    'Tony van Dijck',
#    'Rutte',
#    'Tony van Dijck',
#    'voorzitter',
#    'Tony van Dijck',
#    'Rutte',
#    'Tony van Dijck',
#    'Rutte',
#    'voorzitter',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Pechtold',
#    'Rutte',
#    'Madlener',
#    'Rutte',
#    'Madlener',
#    'Rutte',
#    'voorzitter',
#    'Van Bommel',
#    'Rutte',
#    'Van Bommel',
#    'Rutte',
#    'Tony van Dijck',
#    'Rutte',
#    'Tony van Dijck',
#    'Rutte',
#    'voorzitter',
#    'Van Bommel',
#    'Pechtold',
#    'voorzitter',
#    'Tony van Dijck',
#    'Servaes',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'Van Haersma Buma',
#    'Rutte',
#    'voorzitter',
#    'Rutte',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-102-34': ['Naleving Handboek voor aantredende bewindspersonen',
#   'Voorzitter',
#   204,
#   ['voorzitter',
#    'Van Veldhoven',
#    'Elias',
#    'Van Veldhoven',
#    'Elias',
#    'Van Veldhoven',
#    'Elias',
#    'voorzitter',
#    'Bisschop',
#    'Van Veldhoven',
#    'Bisschop',
#    'voorzitter',
#    'Bisschop',
#    'Van Veldhoven',
#    'Bisschop',
#    'Van Veldhoven',
#    'Van Tongeren',
#    'Van Veldhoven',
#    'Van Tongeren',
#    'Van Veldhoven',
#    'Klein',
#    'Van Veldhoven',
#    'Klein',
#    'Van Veldhoven',
#    'Van Tongeren',
#    'voorzitter',
#    'Van Tongeren',
#    'voorzitter',
#    'Van Tongeren',
#    'De Rouwe',
#    'Van Tongeren',
#    'De Rouwe',
#    'Van Tongeren',
#    'Bashir',
#    'De Rouwe',
#    'Bashir',
#    'De Rouwe',
#    'voorzitter',
#    'Elias',
#    'Van Veldhoven',
#    'Elias',
#    'Van Veldhoven',
#    'voorzitter',
#    'Elias',
#    'Van Veldhoven',
#    'Elias',
#    'voorzitter',
#    'De Rouwe',
#    'Elias',
#    'voorzitter',
#    'De Rouwe',
#    'Elias',
#    'Van Tongeren',
#    'Elias',
#    'Van Tongeren',
#    'Elias',
#    'Van Tongeren',
#    'Elias',
#    'Van Veldhoven',
#    'Elias',
#    'Van Veldhoven',
#    'Elias',
#    'Van Veldhoven',
#    'Elias',
#    'Van Tongeren',
#    'Elias',
#    'Van Tongeren',
#    'Elias',
#    'Dik-Faber',
#    'Bisschop',
#    'Van Veldhoven',
#    'Bisschop',
#    'Van Veldhoven',
#    'Bisschop',
#    'Van Tongeren',
#    'Bisschop',
#    'Van Tongeren',
#    'Bisschop',
#    'Bashir',
#    'Bisschop',
#    'Bashir',
#    'Bisschop',
#    'Van Tongeren',
#    'Bisschop',
#    'Van Tongeren',
#    'Bisschop',
#    'voorzitter',
#    'De Graaf',
#    'Klein',
#    'Kuiken',
#    'Van Veldhoven',
#    'Kuiken',
#    'Van Veldhoven',
#    'Kuiken',
#    'Van Tongeren',
#    'Kuiken',
#    'Van Tongeren',
#    'Kuiken',
#    'Van Veldhoven',
#    'Kuiken',
#    'De Rouwe',
#    'voorzitter',
#    'Schultz van Haegen-Maas Geesteranus',
#    'voorzitter',
#    'De Rouwe',
#    'Schultz van Haegen-Maas Geesteranus',
#    'De Rouwe',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Tongeren',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Tongeren',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Veldhoven',
#    'voorzitter',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Veldhoven',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Tongeren',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Tongeren',
#    'Schultz van Haegen-Maas Geesteranus',
#    'voorzitter',
#    'Schultz van Haegen-Maas Geesteranus',
#    'De Rouwe',
#    'Schultz van Haegen-Maas Geesteranus',
#    'De Rouwe',
#    'Schultz van Haegen-Maas Geesteranus',
#    'De Rouwe',
#    'Schultz van Haegen-Maas Geesteranus',
#    'voorzitter',
#    'De Rouwe',
#    'Schultz van Haegen-Maas Geesteranus',
#    'De Rouwe',
#    'Schultz van Haegen-Maas Geesteranus',
#    'De Rouwe',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Veldhoven',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Veldhoven',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Bashir',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Bashir',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Tongeren',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Tongeren',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Bashir',
#    'Schultz van Haegen-Maas Geesteranus',
#    'voorzitter',
#    'Rutte',
#    'De Rouwe',
#    'Rutte',
#    'De Rouwe',
#    'Rutte',
#    'De Rouwe',
#    'Rutte',
#    'voorzitter',
#    'De Rouwe',
#    'Rutte',
#    'Van Tongeren',
#    'Rutte',
#    'Van Tongeren',
#    'Rutte',
#    'Van Veldhoven',
#    'Rutte',
#    'Van Veldhoven',
#    'Rutte',
#    'Van Veldhoven',
#    'Rutte',
#    'Van Veldhoven',
#    'Rutte',
#    'Van Tongeren',
#    'Rutte',
#    'Van Tongeren',
#    'Rutte',
#    'Van Veldhoven',
#    'Rutte',
#    'voorzitter',
#    'Rutte',
#    'Van Veldhoven',
#    'Rutte',
#    'voorzitter',
#    'Van Veldhoven',
#    'voorzitter',
#    'Van Tongeren',
#    'Van Tongeren',
#    'Van Veldhoven',
#    'Van Veldhoven',
#    'Elias',
#    'Van Veldhoven',
#    'Elias',
#    'Van Veldhoven',
#    'voorzitter',
#    'Van Veldhoven',
#    'voorzitter',
#    'voorzitter',
#    'Rutte',
#    'voorzitter',
#    'Van Veldhoven',
#    'Rutte',
#    'Van Veldhoven',
#    'voorzitter']],
#  '20122013-102-35': ['GGZ',
#   'Voorzitter',
#   17,
#   ['voorzitter',
#    'Leijten',
#    'Kuzu',
#    'Pia Dijkstra',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'voorzitter',
#    'Pia Dijkstra',
#    'Schippers',
#    'voorzitter']],
#  '20122013-102-36': ['Wet kwaliteit, klachten en geschillen zorg',
#   'Voorzitter',
#   108,
#   ['voorzitter',
#    'Leijten',
#    'voorzitter',
#    'Schippers',
#    'voorzitter',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'voorzitter',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Kuzu',
#    'Schippers',
#    'Klever',
#    'Schippers',
#    'Klever',
#    'Schippers',
#    'Van der Staaij',
#    'Schippers',
#    'Van der Staaij',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'voorzitter',
#    'Leijten',
#    'Van der Staaij',
#    'Bruins Slot',
#    'Van der Staaij',
#    'Bruins Slot',
#    'Van der Staaij',
#    'Bruins Slot',
#    'Van der Staaij',
#    'Van der Staaij',
#    'Bruins Slot',
#    'Bruins Slot',
#    'Kuzu',
#    'Van Veen',
#    'Leijten',
#    'Van Veen',
#    'Leijten',
#    'Van Veen',
#    'Van Veen',
#    'Pia Dijkstra',
#    'Klever',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Van Veen',
#    'Schippers',
#    'Van der Staaij',
#    'Schippers',
#    'Van der Staaij',
#    'Schippers',
#    'Van Veen',
#    'Schippers',
#    'Van der Staaij',
#    'voorzitter',
#    'Schippers',
#    'Bruins Slot',
#    'Schippers',
#    'Bruins Slot',
#    'Schippers',
#    'Kuzu',
#    'Schippers',
#    'Kuzu',
#    'Schippers',
#    'voorzitter',
#    'voorzitter',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Pia Dijkstra',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Leijten',
#    'Schippers',
#    'Bruins Slot',
#    'Schippers',
#    'Bruins Slot',
#    'Schippers',
#    'voorzitter']],
#  '20122013-102-37': ['Sluiting', 'Voorzitter', 0, []],
#  '20122013-102-38': ['Ingekomen stukken', 'Voorzitter', 0, []],
#  '20122013-102-4': ['Vragenuur: Vragen Van Weyenberg',
#   'Van Weyenberg',
#   11,
#   ['Klijnsma',
#    'Van Weyenberg',
#    'Klijnsma',
#    'voorzitter',
#    'Ulenbelt',
#    'Klijnsma',
#    'Lodders',
#    'Klijnsma',
#    'Omtzigt',
#    'Klijnsma',
#    'voorzitter']],
#  '20122013-102-5': ['Vragenuur: Vragen Bisschop',
#   'Bisschop',
#   12,
#   ['Schultz van Haegen-Maas Geesteranus',
#    'Bisschop',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Van Veldhoven',
#    'Schultz van Haegen-Maas Geesteranus',
#    'De Graaf',
#    'Schultz van Haegen-Maas Geesteranus',
#    'Bashir',
#    'Schultz van Haegen-Maas Geesteranus',
#    'De Boer',
#    'Schultz van Haegen-Maas Geesteranus',
#    'voorzitter']],
#  '20122013-102-6': ['Vragenuur: Vragen Sjoerdsma',
#   'Sjoerdsma',
#   13,
#   ['Timmermans',
#    'Sjoerdsma',
#    'Timmermans',
#    'Sjoerdsma',
#    'Timmermans',
#    'voorzitter',
#    'Omtzigt',
#    'Timmermans',
#    'Voordewind',
#    'Timmermans',
#    'Servaes',
#    'Timmermans',
#    'voorzitter']],
#  '20122013-102-7': ['Mededelingen',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-102-8': ['Regeling van werkzaamheden',
#   'Voorzitter',
#   159,
#   ['voorzitter',
#    'voorzitter',
#    'Van Meenen',
#    'voorzitter',
#    'Jasper van Dijk',
#    'Beertema',
#    'Duisenberg',
#    'voorzitter',
#    'Rog',
#    'Voortman',
#    'Mohandis',
#    'voorzitter',
#    'Bisschop',
#    'Voordewind',
#    'voorzitter',
#    'Van Meenen',
#    'voorzitter',
#    'Van Meenen',
#    'voorzitter',
#    'Van Meenen',
#    'voorzitter',
#    'Van Meenen',
#    'voorzitter',
#    'Jasper van Dijk',
#    'Van Meenen',
#    'Jasper van Dijk',
#    'Van Meenen',
#    'voorzitter',
#    'Jasper van Dijk',
#    'Voordewind',
#    'Beertema',
#    'Voortman',
#    'voorzitter',
#    'Voortman',
#    'Rog',
#    'Bisschop',
#    'Ypma',
#    'Straus',
#    'voorzitter',
#    'Van Meenen',
#    'voorzitter',
#    'Sjoerdsma',
#    'voorzitter',
#    'Ten Broeke',
#    'voorzitter',
#    'Ten Broeke',
#    'voorzitter',
#    'Maij',
#    'voorzitter',
#    'Van Bommel',
#    'Van Ojik',
#    'voorzitter',
#    'De Graaf',
#    'voorzitter',
#    'Bashir',
#    'voorzitter',
#    'Kuiken',
#    'voorzitter',
#    'Bisschop',
#    'voorzitter',
#    'Van Veldhoven',
#    'voorzitter',
#    'Elias',
#    'voorzitter',
#    'Voordewind',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'Fritsma',
#    'voorzitter',
#    'Fritsma',
#    'voorzitter',
#    'Van Hijum',
#    'voorzitter',
#    'Voortman',
#    'Maij',
#    'voorzitter',
#    'Schouw',
#    'voorzitter',
#    'Azmani',
#    'voorzitter',
#    'Thieme',
#    'Van der Staaij',
#    'voorzitter',
#    'Voordewind',
#    'voorzitter',
#    'Ouwehand',
#    'voorzitter',
#    'Graus',
#    'voorzitter',
#    'Omtzigt',
#    'voorzitter',
#    'Van Veldhoven',
#    'voorzitter',
#    'Bashir',
#    'voorzitter',
#    'Elias',
#    'voorzitter',
#    'Kuiken',
#    'Van Tongeren',
#    'voorzitter',
#    'Van Tongeren',
#    'De Rouwe',
#    'Bisschop',
#    'voorzitter',
#    'Ouwehand',
#    'De Graaf',
#    'Klein',
#    'voorzitter',
#    'Van Veldhoven',
#    'voorzitter',
#    'Van Veldhoven',
#    'voorzitter',
#    'Van Veldhoven',
#    'Agnes Mulder',
#    'Van Tongeren',
#    'Paulus Jansen',
#    'Leegte',
#    'voorzitter',
#    'Jasper van Dijk',
#    'voorzitter',
#    'Jasper van Dijk',
#    'voorzitter',
#    'Jasper van Dijk',
#    'voorzitter',
#    'Voordewind',
#    'voorzitter',
#    'Hachchi',
#    'voorzitter',
#    'Jasper van Dijk',
#    'voorzitter',
#    'De Roon',
#    'Knops',
#    'voorzitter',
#    'Knops',
#    'Dijkgraaf',
#    'Segers',
#    'Eijsink',
#    'voorzitter',
#    'Van Ojik',
#    'Vuijk',
#    'voorzitter',
#    'Krol',
#    'voorzitter',
#    'Hachchi',
#    'voorzitter',
#    'Thieme',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Van Meenen',
#    'voorzitter',
#    'Ouwehand',
#    'voorzitter']],
#  '20122013-102-9': ['Stemmingen moties raming Tweede Kamer',
#   'Voorzitter',
#   11,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-103-1': ['103e vergadering', 'Voorzitter', 0, []],
#  '20122013-103-10': ['Cultuuronderwerpen',
#   'Bergkamp',
#   39,
#   ['voorzitter',
#    'Bergkamp',
#    'Monasch',
#    'Jasper van Dijk',
#    'Venrooy-van Ark',
#    'voorzitter',
#    'Jasper van Dijk',
#    'Venrooy-van Ark',
#    'voorzitter',
#    'Keijzer',
#    'Bussemaker',
#    'voorzitter',
#    'Bussemaker',
#    'Bergkamp',
#    'voorzitter',
#    'Bussemaker',
#    'Bergkamp',
#    'Bussemaker',
#    'Keijzer',
#    'Bussemaker',
#    'Keijzer',
#    'Bussemaker',
#    'voorzitter',
#    'Keijzer',
#    'Bussemaker',
#    'Bergkamp',
#    'voorzitter',
#    'Bussemaker',
#    'Jasper van Dijk',
#    'Bussemaker',
#    'voorzitter',
#    'Venrooy-van Ark',
#    'Monasch',
#    'Venrooy-van Ark',
#    'Bussemaker',
#    'Venrooy-van Ark',
#    'Bussemaker',
#    'Venrooy-van Ark',
#    'voorzitter']],
#  '20122013-103-11': ['Mededelingen', 'Voorzitter', 1, ['voorzitter']],
#  '20122013-103-12': ['Regeling van werkzaamheden',
#   'Voorzitter',
#   94,
#   ['voorzitter',
#    'voorzitter',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Van Oosten',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'Vermeij',
#    'voorzitter',
#    'Gesthuizen',
#    'Krol',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Gesthuizen',
#    'voorzitter',
#    'Helder',
#    'voorzitter',
#    'Karabulut',
#    'voorzitter',
#    'Schouw',
#    'voorzitter',
#    'Schouw',
#    'voorzitter',
#    'Agema',
#    'voorzitter',
#    'Agema',
#    'Thieme',
#    'Dikkers',
#    'voorzitter',
#    'Van der Staaij',
#    'voorzitter',
#    'Van Gerven',
#    'voorzitter',
#    'Klaver',
#    'voorzitter',
#    'Klaver',
#    'Krol',
#    'Dik-Faber',
#    'voorzitter',
#    'Lodders',
#    'Geurts',
#    'voorzitter',
#    'Schouw',
#    'voorzitter',
#    'Remco Dijkstra',
#    'voorzitter',
#    'Ouwehand',
#    'voorzitter',
#    'Leijten',
#    'voorzitter',
#    'Agema',
#    'Krol',
#    'Voortman',
#    'voorzitter',
#    'Bergkamp',
#    'voorzitter',
#    'Bergkamp',
#    'Dik-Faber',
#    'Ouwehand',
#    'Otwin van Dijk',
#    'voorzitter',
#    'Otwin van Dijk',
#    'voorzitter',
#    'Otwin van Dijk',
#    'voorzitter',
#    'Keijzer',
#    'voorzitter',
#    "Van 't Wout",
#    'Van der Staaij',
#    'voorzitter',
#    'Leijten',
#    'voorzitter',
#    'Keijzer',
#    'voorzitter',
#    'Otwin van Dijk',
#    'voorzitter',
#    'Agema',
#    'Leijten',
#    'voorzitter',
#    'Leijten',
#    'voorzitter',
#    'Leijten',
#    'voorzitter']],
#  '20122013-103-13': ['Online betalingsverkeer',
#   'Voorzitter',
#   24,
#   ['voorzitter',
#    'Nijboer',
#    'Nijboer',
#    'Nijboer',
#    'Verhoeven',
#    'Verhoeven',
#    'voorzitter',
#    'Merkies',
#    'voorzitter',
#    'Aukje de Vries',
#    'Dijsselbloem',
#    'Verhoeven',
#    'voorzitter',
#    'Dijsselbloem',
#    'voorzitter',
#    'Dijsselbloem',
#    'Verhoeven',
#    'voorzitter',
#    'Dijsselbloem',
#    'Merkies',
#    'Dijsselbloem',
#    'Merkies',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-103-14': ['Voorjaarsnota 2013',
#   'Voorzitter',
#   208,
#   ['voorzitter',
#    'Tony van Dijck',
#    'Harbers',
#    'Van Hijum',
#    'Harbers',
#    'Van Hijum',
#    'Harbers',
#    'Koolmees',
#    'Harbers',
#    'Koolmees',
#    'Harbers',
#    'Merkies',
#    'Harbers',
#    'Merkies',
#    'Harbers',
#    'Tony van Dijck',
#    'Harbers',
#    'Tony van Dijck',
#    'Harbers',
#    'Merkies',
#    'Koolmees',
#    'Merkies',
#    'Koolmees',
#    'Merkies',
#    'Nijboer',
#    'Merkies',
#    'Nijboer',
#    'Merkies',
#    'Dijkgraaf',
#    'Merkies',
#    'Dijkgraaf',
#    'Merkies',
#    'Van Hijum',
#    'Merkies',
#    'Van Hijum',
#    'Merkies',
#    'Harbers',
#    'Merkies',
#    'Harbers',
#    'Merkies',
#    'Nijboer',
#    'Klaver',
#    'Nijboer',
#    'Klaver',
#    'Nijboer',
#    'Van Hijum',
#    'Nijboer',
#    'Van Hijum',
#    'Nijboer',
#    'Koolmees',
#    'Nijboer',
#    'Koolmees',
#    'Nijboer',
#    'Tony van Dijck',
#    'Nijboer',
#    'Tony van Dijck',
#    'Nijboer',
#    'Van Hijum',
#    'Schouten',
#    'Van Hijum',
#    'Schouten',
#    'Van Hijum',
#    'Nijboer',
#    'Van Hijum',
#    'Nijboer',
#    'Van Hijum',
#    'Dijkgraaf',
#    'Van Hijum',
#    'Dijkgraaf',
#    'Van Hijum',
#    'Dijkgraaf',
#    'Van Hijum',
#    'Koolmees',
#    'voorzitter',
#    'Koolmees',
#    'voorzitter',
#    'Dijkgraaf',
#    'Koolmees',
#    'Dijkgraaf',
#    'Koolmees',
#    'voorzitter',
#    'Dijsselbloem',
#    'Koolmees',
#    'Schouten',
#    'Koolmees',
#    'Schouten',
#    'Koolmees',
#    'Schouten',
#    'Van Hijum',
#    'Schouten',
#    'Van Hijum',
#    'Schouten',
#    'Klaver',
#    'Dijkgraaf',
#    'Klein',
#    'voorzitter',
#    'Dijsselbloem',
#    'Koolmees',
#    'Dijsselbloem',
#    'voorzitter',
#    'Koolmees',
#    'Dijsselbloem',
#    'Koolmees',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'Tony van Dijck',
#    'Dijsselbloem',
#    'Tony van Dijck',
#    'Dijsselbloem',
#    'Koolmees',
#    'voorzitter',
#    'Koolmees',
#    'voorzitter',
#    'Koolmees',
#    'Dijsselbloem',
#    'Koolmees',
#    'Dijsselbloem',
#    'voorzitter',
#    'Dijsselbloem',
#    'Merkies',
#    'Dijsselbloem',
#    'Merkies',
#    'Dijsselbloem',
#    'Klein',
#    'Dijsselbloem',
#    'Klein',
#    'Dijsselbloem',
#    'Klaver',
#    'Dijsselbloem',
#    'Schouten',
#    'Dijsselbloem',
#    'Van Hijum',
#    'Dijsselbloem',
#    'Van Hijum',
#    'Dijsselbloem',
#    'Van Hijum',
#    'Dijsselbloem',
#    'Schouten',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'Klein',
#    'Dijsselbloem',
#    'Klaver',
#    'Dijsselbloem',
#    'Klaver',
#    'Dijsselbloem',
#    'voorzitter',
#    'Tony van Dijck',
#    'Dijsselbloem',
#    'Tony van Dijck',
#    'Dijsselbloem',
#    'Tony van Dijck',
#    'voorzitter',
#    'Klaver',
#    'Dijsselbloem',
#    'Merkies',
#    'Dijsselbloem',
#    'Merkies',
#    'Dijsselbloem',
#    'voorzitter',
#    'Dijsselbloem',
#    'voorzitter',
#    'Tony van Dijck',
#    'Klaver',
#    'Tony van Dijck',
#    'Klaver',
#    'Tony van Dijck',
#    'Klaver',
#    'Tony van Dijck',
#    'voorzitter',
#    'Tony van Dijck',
#    'Klaver',
#    'voorzitter',
#    'Harbers',
#    'Merkies',
#    'Nijboer',
#    'Van Hijum',
#    'Koolmees',
#    'Koolmees',
#    'Schouten',
#    'Klaver',
#    'Klein',
#    'Dijsselbloem',
#    'Merkies',
#    'Dijsselbloem',
#    'Merkies',
#    'Dijsselbloem',
#    'voorzitter',
#    'Koolmees',
#    'Dijsselbloem',
#    'Koolmees',
#    'Dijsselbloem',
#    'voorzitter',
#    'Dijsselbloem',
#    'voorzitter',
#    'Dijsselbloem',
#    'Klein',
#    'Dijsselbloem',
#    'Schouten',
#    'Dijsselbloem',
#    'voorzitter',
#    'voorzitter']],
#  '20122013-103-15': ['Verplicht schatkistbankieren',
#   'Voorzitter',
#   78,
#   ['voorzitter',
#    'Van Hijum',
#    'voorzitter',
#    'Tony van Dijck',
#    'Dijkgraaf',
#    'Tony van Dijck',
#    'voorzitter',
#    'Tony van Dijck',
#    'Dijkgraaf',
#    'voorzitter',
#    'Tony van Dijck',
#    'Dijkgraaf',
#    'Koolmees',
#    'voorzitter',
#    'Dijkgraaf',
#    'Koolmees',
#    'Dijkgraaf',
#    'Koolmees',
#    'Dijkgraaf',
#    'Koolmees',
#    'Dijkgraaf',
#    'Koolmees',
#    'Klein',
#    'Litjens',
#    'Groot',
#    'voorzitter',
#    'Dijsselbloem',
#    'Groot',
#    'Dijsselbloem',
#    'Van Hijum',
#    'Dijsselbloem',
#    'Van Hijum',
#    'Dijsselbloem',
#    'Klein',
#    'Dijsselbloem',
#    'Klein',
#    'Dijsselbloem',
#    'Tony van Dijck',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'voorzitter',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'voorzitter',
#    'Van Hijum',
#    'Dijkgraaf',
#    'Klein',
#    'voorzitter',
#    'Klein',
#    'voorzitter',
#    'Dijsselbloem',
#    'voorzitter',
#    'Dijsselbloem',
#    'Klein',
#    'Dijsselbloem',
#    'Klein',
#    'Dijsselbloem',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'voorzitter',
#    'Dijkgraaf',
#    'Dijsselbloem',
#    'Van Hijum',
#    'Dijsselbloem',
#    'Van Hijum',
#    'Dijsselbloem',
#    'Tony van Dijck',
#    'Dijsselbloem',
#    'voorzitter',
#    'Tony van Dijck',
#    'Dijsselbloem',
#    'voorzitter']],
#  '20122013-103-16': ['Sluiting', 'Voorzitter', 0, []],
#  '20122013-103-17': ['Ingekomen stukken', 'Voorzitter', 0, []],
#  '20122013-103-2': ['Mededelingen',
#   'Voorzitter',
#   2,
#   ['voorzitter', 'voorzitter']],
#  '20122013-103-3': ['Biotechnologie',
#   'Voorzitter',
#   34,
#   ['voorzitter',
#    'Dikkers',
#    'Van Gerven',
#    'Van Gerven',
#    'Dik-Faber',
#    'De Liefde',
#    'Klaver',
#    'Geurts',
#    'Ouwehand',
#    'voorzitter',
#    'Dijksma',
#    'Dikkers',
#    'Dijksma',
#    'voorzitter',
#    'Dijksma',
#    'voorzitter',
#    'Ouwehand',
#    'Dijksma',
#    'voorzitter',
#    'Dijksma',
#    'voorzitter',
#    'Dijksma',
#    'voorzitter',
#    'Dijksma',
#    'voorzitter',
#    'Dijksma',
#    'Dik-Faber',
#    'Dijksma',
#    'Mansveld',
#    'Klaver',
#    'Mansveld',
#    'voorzitter',
#    'Mansveld',
#    'voorzitter']],
#  '20122013-103-4': ['Visserij',
#   'Voorzitter',
#   30,
#   ['voorzitter',
#    'Ouwehand',
#    'Ouwehand',
#    'Graus',
#    'Graus',
#    'Graus',
#    'Dijksma',
#    'Ouwehand',
#    'Dijksma',
#    'voorzitter',
#    'Ouwehand',
#    'Dijksma',
#    'Graus',
#    'Dijksma',
#    'Graus',
#    'Dijksma',
#    'voorzitter',
#    'Dijksma',
#    'voorzitter',
#    'Dijkgraaf',
#    'Dijksma',
#    'Graus',
#    'Dijksma',
#    'Graus',
#    'Dijksma',
#    'Graus',
#    'Dijksma',
#    'voorzitter',
#    'Dijksma',
#    'voorzitter']],
#  '20122013-103-5': ['Ganzenbeleid',
#   'Voorzitter',
#   25,
#   ['voorzitter',
#    'Thieme',
#    'Thieme',
#    'voorzitter',
#    'Graus',
#    'Houwers',
#    'Van Gerven',
#    'Van Gerven',
#    'voorzitter',
#    'Dijksma',
#    'Thieme',
#    'Dijksma',
#    'Thieme',
#    'Dijksma',
#    'Thieme',
#    'Dijksma',
#    'Graus',
#    'Dijksma',
#    'Graus',
#    'Dijksma',
#    'Van Gerven',
#    'Dijksma',
#    'Van Gerven',
#    'Dijksma',
#    'voorzitter']],
#  '20122013-103-6': ['Invulling van de subsidietaakstelling onderwijs en onderzoek',
#   'Van Meenen',
#   24,
#   ['Voordewind',
#    'Bisschop',
#    'Lucas',
#    'Van Meenen',
#    'Lucas',
#    'Jasper van Dijk',
#    'Jasper van Dijk',
#    'voorzitter',
#    'Rog',
#    'Mohandis',
#    'voorzitter',
#    'Bussemaker',
#    'voorzitter',
#    'Dekker',
#    'Van Meenen',
#    'Dekker',
#    'voorzitter',
#    'Jasper van Dijk',
#    'Dekker',
#    'voorzitter',
#    'Dekker',
#    'voorzitter',
#    'Dekker',
#    'voorzitter']],
#  '20122013-103-7': ['Zorgverzekeringswet, Pakketmaatregelen en Ruwaard van Putten ziekenhuis',
#   'Voorzitter',
#   36,
#   ['voorzitter',
#    'Leijten',
#    'Leijten',
#    'Pia Dijkstra',
#    'Klever',
#    'Voortman',
#    'Voortman',
#    'Van der Staaij',
#    'Wolbert',
#    'voorzitter',
#    'Leijten',
#    'Wolbert',
#    'Bruins Slot',
#    'Bruins Slot',
#    'Bruins Slot',
#    'Anne Mulder',
#    'voorzitter',
#    'Schippers',
#    'voorzitter',
#    'Leijten',
#    'Schippers',
#    'Pia Dijkstra',
#    'voorzitter',
#    'Schippers',
#    'voorzitter',
#    'Schippers',
#    'Van der Staaij',
#    'Schippers',
#    'Van der Staaij',
#    'Schippers',
#    'Bruins Slot',
#    'Schippers',
#    'Bruins Slot',
#    'voorzitter',
#    'Schippers',
#    'voorzitter']]}

# %%
bla = {}
bla[1] = ['test1', 'hoi2']
bla[2] = ['test2', 'hoi3']

# %%
dictje['20122013-10-15']
# Out:
# ['Begroting Algemene Zaken en begroting van de Koning',
#  'Recourt',
#  64,
#  ['Van Raak',
#   'Recourt',
#   'Van Raak',
#   'Recourt',
#   'Van Raak',
#   'Recourt',
#   'Pechtold',
#   'Recourt',
#   'Pechtold',
#   'Recourt',
#   'Pechtold',
#   'Recourt',
#   'voorzitter',
#   'Van Ojik',
#   'Recourt',
#   'Van Ojik',
#   'Recourt',
#   'Van der Burg',
#   'Thieme',
#   'Van der Burg',
#   'Thieme',
#   'Van der Burg',
#   'Pechtold',
#   'Van der Burg',
#   'Pechtold',
#   'Van der Burg',
#   'voorzitter',
#   'Pechtold',
#   'Van der Burg',
#   'Pechtold',
#   'Bosma',
#   'Van Toorenburg',
#   'Pechtold',
#   'Van Toorenburg',
#   'Pechtold',
#   'Van Toorenburg',
#   'Pechtold',
#   'Van Toorenburg',
#   'voorzitter',
#   'Bosma',
#   'Van Toorenburg',
#   'Bosma',
#   'Van Toorenburg',
#   'Van Raak',
#   'Recourt',
#   'Van Raak',
#   'Van der Burg',
#   'Van Raak',
#   'Van der Burg',
#   'Van Raak',
#   'Van der Burg',
#   'Van Raak',
#   'Recourt',
#   'Van Raak',
#   'Recourt',
#   'Van Raak',
#   'Pechtold',
#   'Van Ojik',
#   'Van der Staaij',
#   'Pechtold',
#   'Van der Staaij',
#   'Pechtold',
#   'Van der Staaij',
#   'Thieme']]

# %%
test = pd.DataFrame.from_dict(dictje, orient='index')
test
# Out:
#                                                                  0    1  \
# 20122013-1-1                                        1e vergadering    0
# 20122013-1-2                                          Mededelingen    1
# 20122013-1-3                                        Begroting 2013    6
# 20122013-1-4                            Regeling van werkzaamheden    1
# 20122013-10-1                                      10e vergadering    0
# 20122013-10-10                                  Stemmingen Postwet    3
# 20122013-10-11           Stemmingen ontslagen sociale werkplaatsen    3
# 20122013-10-12   Stemmingen Beperkingengebied buitenlandse luch...    1
# 20122013-10-13        Stemmingen algemene financiële beschouwingen   11
# 20122013-10-14   Stemmingen Subsidiariteitstoets veiligheid mot...    1
# 20122013-10-15   Begroting Algemene Zaken en begroting van de K...   64
# 20122013-10-16   Openbare lichamen Bonaire, Sint Eustatius en Saba   93
# 20122013-10-17                                   Ingekomen stukken    0
# 20122013-10-2                                            Vragenuur   10
# 20122013-10-3                                            Vragenuur   19
# 20122013-10-4                                            Vragenuur    9
# 20122013-10-5                                            Vragenuur   10
# 20122013-10-6                                            Vragenuur   12
# 20122013-10-7                                         Mededelingen    2
# 20122013-10-8                           Regeling van werkzaamheden   81
# 20122013-10-9                    Stemmingen Wet schadeloosstelling    2
# 20122013-100-1                                    100e vergadering    0
# 20122013-100-10                                  Ingekomen stukken    0
# 20122013-100-2                                        Mededelingen    1
# 20122013-100-3   Aanbevelingen Europese Commissie extra bezuini...  247
# 20122013-100-4                                        Mededelingen    1
# 20122013-100-5                          Regeling van werkzaamheden   48
# 20122013-100-6      Aanbevelingen Europese Commissie bezuinigingen  174
# 20122013-100-7                                 Agenda Europese top  191
# 20122013-100-8                      Stemmingen moties Europese Top   10
# ...                                                            ...  ...
# 20122013-102-30  Stemmingen moties Jaarverslag ministerie van V...    3
# 20122013-102-31  Stemmingen moties Jaarverslag ministerie van E...    4
# 20122013-102-32  Stemming motie Beleidsnota "Wat de wereld verd...    1
# 20122013-102-33                               Verslag Europese top   91
# 20122013-102-34  Naleving Handboek voor aantredende bewindspers...  204
# 20122013-102-35                                                GGZ   17
# 20122013-102-36         Wet kwaliteit, klachten en geschillen zorg  108
# 20122013-102-37                                           Sluiting    0
# 20122013-102-38                                  Ingekomen stukken    0
# 20122013-102-4                     Vragenuur: Vragen Van Weyenberg   11
# 20122013-102-5                          Vragenuur: Vragen Bisschop   12
# 20122013-102-6                         Vragenuur: Vragen Sjoerdsma   13
# 20122013-102-7                                        Mededelingen    2
# 20122013-102-8                          Regeling van werkzaamheden  159
# 20122013-102-9               Stemmingen moties raming Tweede Kamer   11
# 20122013-103-1                                    103e vergadering    0
# 20122013-103-10                                 Cultuuronderwerpen   39
# 20122013-103-11                                       Mededelingen    1
# 20122013-103-12                         Regeling van werkzaamheden   94
# 20122013-103-13                            Online betalingsverkeer   24
# 20122013-103-14                                 Voorjaarsnota 2013  208
# 20122013-103-15                       Verplicht schatkistbankieren   78
# 20122013-103-16                                           Sluiting    0
# 20122013-103-17                                  Ingekomen stukken    0
# 20122013-103-2                                        Mededelingen    2
# 20122013-103-3                                      Biotechnologie   34
# 20122013-103-4                                            Visserij   30
# 20122013-103-5                                        Ganzenbeleid   25
# 20122013-103-6   Invulling van de subsidietaakstelling onderwij...   24
# 20122013-103-7   Zorgverzekeringswet, Pakketmaatregelen en Ruwa...   36
#
#                                                                  2
# 20122013-1-1                                                    []
# 20122013-1-2                                          [voorzitter]
# 20122013-1-3     [voorzitter, De Jager, De Jager, voorzitter, D...
# 20122013-1-4                                          [voorzitter]
# 20122013-10-1                                                   []
# 20122013-10-10                [voorzitter, voorzitter, voorzitter]
# 20122013-10-11                [voorzitter, voorzitter, voorzitter]
# 20122013-10-12                                        [voorzitter]
# 20122013-10-13   [voorzitter, voorzitter, voorzitter, voorzitte...
# 20122013-10-14                                        [voorzitter]
# 20122013-10-15   [Van Raak, Recourt, Van Raak, Recourt, Van Raa...
# 20122013-10-16   [voorzitter, Spies, voorzitter, Segers, voorzi...
# 20122013-10-17                                                  []
# 20122013-10-2    [Opstelten, Marcouch, Opstelten, Marcouch, Ops...
# 20122013-10-3    [Schippers, Bruins Slot, Schippers, Bruins Slo...
# 20122013-10-4    [Weekers, Van Tongeren, Weekers, Van Tongeren,...
# 20122013-10-5    [Spies, Paulus Jansen, Spies, Paulus Jansen, S...
# 20122013-10-6    [voorzitter, Voordewind, voorzitter, Leers, Vo...
# 20122013-10-7                             [voorzitter, voorzitter]
# 20122013-10-8    [voorzitter, voorzitter, voorzitter, Agema, vo...
# 20122013-10-9                             [voorzitter, voorzitter]
# 20122013-100-1                                                  []
# 20122013-100-10                                                 []
# 20122013-100-2                                        [voorzitter]
# 20122013-100-3   [voorzitter, Wilders, Roemer, Pechtold, Van Ha...
# 20122013-100-4                                        [voorzitter]
# 20122013-100-5   [voorzitter, voorzitter, voorzitter, Gesthuize...
# 20122013-100-6   [Roemer, Rutte, Pechtold, voorzitter, Pechtold...
# 20122013-100-7   [voorzitter, Van Bommel, Klaver, Schouten, Ver...
# 20122013-100-8   [voorzitter, voorzitter, voorzitter, voorzitte...
# ...                                                            ...
# 20122013-102-30               [voorzitter, voorzitter, voorzitter]
# 20122013-102-31   [voorzitter, voorzitter, voorzitter, voorzitter]
# 20122013-102-32                                       [voorzitter]
# 20122013-102-33  [voorzitter, Van Bommel, Pechtold, Verheijen, ...
# 20122013-102-34  [voorzitter, Van Veldhoven, Elias, Van Veldhov...
# 20122013-102-35  [voorzitter, Leijten, Kuzu, Pia Dijkstra, Schi...
# 20122013-102-36  [voorzitter, Leijten, voorzitter, Schippers, v...
# 20122013-102-37                                                 []
# 20122013-102-38                                                 []
# 20122013-102-4   [Klijnsma, Van Weyenberg, Klijnsma, voorzitter...
# 20122013-102-5   [Schultz van Haegen-Maas Geesteranus, Bisschop...
# 20122013-102-6   [Timmermans, Sjoerdsma, Timmermans, Sjoerdsma,...
# 20122013-102-7                            [voorzitter, voorzitter]
# 20122013-102-8   [voorzitter, voorzitter, Van Meenen, voorzitte...
# 20122013-102-9   [voorzitter, voorzitter, voorzitter, voorzitte...
# 20122013-103-1                                                  []
# 20122013-103-10  [voorzitter, Bergkamp, Monasch, Jasper van Dij...
# 20122013-103-11                                       [voorzitter]
# 20122013-103-12  [voorzitter, voorzitter, voorzitter, Gesthuize...
# 20122013-103-13  [voorzitter, Nijboer, Nijboer, Nijboer, Verhoe...
# 20122013-103-14  [voorzitter, Tony van Dijck, Harbers, Van Hiju...
# 20122013-103-15  [voorzitter, Van Hijum, voorzitter, Tony van D...
# 20122013-103-16                                                 []
# 20122013-103-17                                                 []
# 20122013-103-2                            [voorzitter, voorzitter]
# 20122013-103-3   [voorzitter, Dikkers, Van Gerven, Van Gerven, ...
# 20122013-103-4   [voorzitter, Ouwehand, Ouwehand, Graus, Graus,...
# 20122013-103-5   [voorzitter, Thieme, Thieme, voorzitter, Graus...
# 20122013-103-6   [Voordewind, Bisschop, Lucas, Van Meenen, Luca...
# 20122013-103-7   [voorzitter, Leijten, Leijten, Pia Dijkstra, K...
#
# [100 rows x 3 columns]

# %%
len([])
# Out:
# 0

# %%
# Out:
# 8397

# %%
dictje
# Out:
# ''
